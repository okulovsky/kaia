# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %%
from datasets import load_dataset

dataset = load_dataset("Spierocho/food_json_extract")

# %%
split_dataset = dataset["train"].train_test_split(test_size=0.2, seed=42)

train_dataset = split_dataset["train"]
val_dataset = split_dataset["test"]

dataset = {"train": train_dataset, "validation": val_dataset}

# %%
from transformers import AutoTokenizer

model_name = "Qwen/Qwen3-0.6B"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
def format_prompt(sample):
    user = sample["input"]
    items = sample["output"]
    result = f"USER:{user}\nLIST_LENGTH:{len(items)}\n"
    result += "\n".join(
        [
            f"[{i}]FOOD:{item['food']},UNIT:{item['unit']},QUANTITY:{int(item['quantity'] or 0)}"
            for i, item in enumerate(items, 1)
        ]
    )
    result += tokenizer.eos_token
    return result

# %%
dataset["train"] = dataset["train"].map(lambda x: {"text": format_prompt(x)})
dataset["validation"] = dataset["validation"].map(lambda x: {"text": format_prompt(x)})

# %%
print(dataset["train"][0]["text"])
# Out:
# USER:I had 100g of Swedish meatballs, 150g of mashed potatoes, 50g lingonberry jam and a glass of milk.
# LIST_LENGTH:4
# [1]FOOD:Swedish meatballs,UNIT:gram,QUANTITY:100
# [2]FOOD:mashed potatoes,UNIT:gram,QUANTITY:150
# [3]FOOD:lingonberry jam,UNIT:gram,QUANTITY:50
# [4]FOOD:milk,UNIT:glass,QUANTITY:1<|im_end|>

# %%
print(tokenizer.tokenize(dataset["train"][0]["text"]))
# Out:
# ['USER', ':I', 'Ġhad', 'Ġ', '1', '0', '0', 'g', 'Ġof', 'ĠSwedish', 'Ġmeat', 'balls', ',', 'Ġ', '1', '5', '0', 'g', 'Ġof', 'Ġmashed', 'Ġpotatoes', ',', 'Ġ', '5', '0', 'g', 'Ġling', 'on', 'berry', 'Ġjam', 'Ġand', 'Ġa', 'Ġglass', 'Ġof', 'Ġmilk', '.Ċ', 'LIST', '_LENGTH', ':', '4', 'Ċ', '[', '1', ']', 'FO', 'OD', ':', 'Sw', 'edish', 'Ġmeat', 'balls', ',', 'UNIT', ':', 'gram', ',', 'QU', 'ANTITY', ':', '1', '0', '0', 'Ċ', '[', '2', ']', 'FO', 'OD', ':m', 'ashed', 'Ġpotatoes', ',', 'UNIT', ':', 'gram', ',', 'QU', 'ANTITY', ':', '1', '5', '0', 'Ċ', '[', '3', ']', 'FO', 'OD', ':', 'ling', 'on', 'berry', 'Ġjam', ',', 'UNIT', ':', 'gram', ',', 'QU', 'ANTITY', ':', '5', '0', 'Ċ', '[', '4', ']', 'FO', 'OD', ':m', 'ilk', ',', 'UNIT', ':', 'glass', ',', 'QU', 'ANTITY', ':', '1', '<|im_end|>']

# %%
max([len(tokenizer(sample["text"])["input_ids"]) for sample in dataset["train"]])
# Out:
# 202

# %%
max([len(tokenizer(sample["text"])["input_ids"]) for sample in dataset["validation"]])
# Out:
# 194

# %%
tokenizer.padding_side
# Out:
# 'right'

# %%
def tokenize(sample):
    prompt = f"USER:{sample['input']}\n"
    prompt_len = len(tokenizer(prompt)["input_ids"])
    tokenized = tokenizer(
        sample["text"],
        padding="max_length",
        max_length=202,
        truncation=True,
    )
    pad_len = tokenized["input_ids"].count(tokenizer.pad_token_id)
    tokenized["labels"] = tokenized["input_ids"].copy()
    tokenized["labels"][:prompt_len] = [-100] * prompt_len
    if pad_len > 0:
        tokenized["labels"][-pad_len:] = [-100] * pad_len

    return tokenized


dataset["train"] = dataset["train"].map(tokenize, batched=False)
dataset["validation"] = dataset["validation"].map(tokenize, batched=False)
# Out:
# Map:   0%|          | 0/656 [00:00<?, ? examples/s]
# Map:   0%|          | 0/165 [00:00<?, ? examples/s]

# %%
from transformers import (
    AutoModelForCausalLM,
    TrainingArguments,
)
from peft import LoraConfig
from trl import SFTTrainer


model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    use_cache=False,
    attn_implementation="eager",
)

# %%
peft_config = LoraConfig(
    r=16,
    lora_alpha=32,
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
    lora_dropout=0.0,
    bias="none",
    task_type="CAUSAL_LM",
)

# %%
training_args = TrainingArguments(
    output_dir="./qwen-nutrition-lora",
    num_train_epochs=3,
    per_device_train_batch_size=8,
    gradient_accumulation_steps=4,
    learning_rate=2e-4,
    logging_steps=10,
    eval_strategy="steps",
    eval_steps=25,
    save_strategy="steps",
    save_steps=25,
    save_total_limit=1,
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,
    report_to=[],
    weight_decay=0.01,
    lr_scheduler_type="cosine",
    warmup_ratio=0.05,
    seed=887,
    fp16=True,
)

trainer = SFTTrainer(
    model=model,
    train_dataset=dataset["train"],
    eval_dataset=dataset["validation"],
    peft_config=peft_config,
    args=training_args,
)

trainer.train()
# Out:
# WARN  Python GIL is enabled: Multi-gpu quant acceleration for MoE models is sub-optimal and multi-core accelerated cpu packing is also disabled. We recommend Python >= 3.13.3t with Pytorch > 2.8 for mult-gpu quantization and multi-cpu packing with env `PYTHON_GIL=0`.
# WARN  Feature `utils/Perplexity` requires python GIL or Python >= 3.13.3T (T for Threading-Free edition of Python) plus Torch 2.8. Feature is currently skipped/disabled.
# INFO  ENV: Auto setting PYTORCH_CUDA_ALLOC_CONF='expandable_segments:True' for memory saving.
# INFO  ENV: Auto setting CUDA_DEVICE_ORDER=PCI_BUS_ID for correctness.
# Truncating train dataset:   0%|          | 0/656 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/165 [00:00<?, ? examples/s]
# INFO:root:cc -pthread -fno-strict-overflow -Wsign-compare -Wunreachable-code -DNDEBUG -g -O3 -Wall -fPIC -fPIC -c /tmp/tmpq3fsim_f/test.c -o /tmp/tmpq3fsim_f/test.o
# INFO:root:cc -pthread /tmp/tmpq3fsim_f/test.o -laio -o /tmp/tmpq3fsim_f/a.out
# /usr/bin/ld: cannot find -laio: No such file or directory
# collect2: error: ld returned 1 exit status
# INFO:root:cc -pthread -fno-strict-overflow -Wsign-compare -Wunreachable-code -DNDEBUG -g -O3 -Wall -fPIC -fPIC -c /tmp/tmpiw3t448p/test.c -o /tmp/tmpiw3t448p/test.o
# INFO:root:cc -pthread /tmp/tmpiw3t448p/test.o -L/usr/local/cuda-12.6 -L/usr/local/cuda-12.6/lib64 -lcufile -o /tmp/tmpiw3t448p/a.out
# INFO:root:cc -pthread -fno-strict-overflow -Wsign-compare -Wunreachable-code -DNDEBUG -g -O3 -Wall -fPIC -fPIC -c /tmp/tmpdsi08a0e/test.c -o /tmp/tmpdsi08a0e/test.o
# INFO:root:cc -pthread /tmp/tmpdsi08a0e/test.o -laio -o /tmp/tmpdsi08a0e/a.out
# /usr/bin/ld: cannot find -laio: No such file or directory
# collect2: error: ld returned 1 exit status
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
#     <div>
#
#       <progress value='63' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [63/63 02:02, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Entropy</th>
#       <th>Num Tokens</th>
#       <th>Mean Token Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>0.049300</td>
#       <td>0.022390</td>
#       <td>3.988996</td>
#       <td>158368.000000</td>
#       <td>0.993997</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.007700</td>
#       <td>0.016005</td>
#       <td>3.816677</td>
#       <td>316736.000000</td>
#       <td>0.996397</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=63, training_loss=0.15368972018006302, metrics={'train_runtime': 124.4509, 'train_samples_per_second': 15.813, 'train_steps_per_second': 0.506, 'total_flos': 1074682920960000.0, 'train_loss': 0.15368972018006302, 'epoch': 3.0})

# %%
trainer.save_model("./qwen-nutrition-lora")

# %%
from transformers import logging

logging.set_verbosity_error()

# %%
from transformers import pipeline
from peft import PeftModel

base_model = AutoModelForCausalLM.from_pretrained(model_name, device_map="cuda")
model = PeftModel.from_pretrained(base_model, "./qwen-nutrition-lora", device_map="cuda")
text_gen = pipeline("text-generation", model=model, tokenizer=tokenizer)

# %%
from tqdm import tqdm


def evaluate_accuracy(
    dataset,
    log_file,
    batch_size=32,
):
    correct = 0
    total = len(dataset)

    with open(log_file, "w") as file:
        for i in tqdm(range(0, total, batch_size)):
            texts = [
                text.replace(tokenizer.eos_token, "")
                for text in dataset[i : i + batch_size]["text"]
            ]
            prefixes = [text.split("\n")[0] + "\n" for text in texts]
            print(repr(prefixes[0]))
            gen_outs = text_gen(
                prefixes,
                num_beams=1,
                do_sample=False,
                batch_size=batch_size,
            )
            for text, gen_out in zip(texts, gen_outs):
                gen_text = gen_out[0]["generated_text"]
                if len(gen_text) >= len(text) and text == gen_text[: len(text)]:
                    correct += 1
                else:
                    print(f"Mismatch:\n{text} ->\n{gen_text}\n", file=file)

    return correct / total

# %%
acc = evaluate_accuracy(dataset["validation"], log_file="eval.log")
print(f"Validation accuracy: {acc:.4f}")
# Out:
#   0%|                                                                                                                                                       | 0/6 [00:00<?, ?it/s]
# 'USER:I had a slice of quiche with 100g of mixed greens and a serving of 200ml of iced tea.\n'
#  17%|███████████████████████▊                                                                                                                       | 1/6 [00:07<00:37,  7.55s/it]
# 'USER:Consumed 150g of quinoa, 100g of grilled chicken breast, a side of steamed broccoli, and a glass of protein shake.\n'
#  17%|███████████████████████▊                                                                                                                       | 1/6 [00:14<01:10, 14.05s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 acc = evaluate_accuracy(dataset["validation"], log_file="eval.log")
#       2 print(f"Validation accuracy: {acc:.4f}")
#
# Cell In[22], line 20, in evaluate_accuracy(dataset, log_file, batch_size)
#      18 prefixes = [text.split("\n")[0] + "\n" for text in texts]
#      19 print(repr(prefixes[0]))
# ---> 20 gen_outs = text_gen(
#      21     prefixes,
#      22     num_beams=1,
#      23     do_sample=False,
#      24     batch_size=batch_size,
#      25 )
#      26 for text, gen_out in zip(texts, gen_outs):
#      27     gen_text = gen_out[0]["generated_text"]
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/transformers/pipelines/text_generation.py:332, in TextGenerationPipeline.__call__(self, text_inputs, **kwargs)
#     330             else:
#     331                 return super().__call__(list(chats), **kwargs)
# --> 332 return super().__call__(text_inputs, **kwargs)
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/transformers/pipelines/base.py:1448, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1444 if can_use_iterator:
#    1445     final_iterator = self.get_iterator(
#    1446         inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1447     )
# -> 1448     outputs = list(final_iterator)
#    1449     return outputs
#    1450 else:
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/transformers/pipelines/pt_utils.py:126, in PipelineIterator.__next__(self)
#     123     return self.loader_batch_item()
#     125 # We're out of items within a batch
# --> 126 item = next(self.iterator)
#     127 processed = self.infer(item, **self.params)
#     128 # We now have a batch of "inferred things".
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/transformers/pipelines/pt_utils.py:127, in PipelineIterator.__next__(self)
#     125 # We're out of items within a batch
#     126 item = next(self.iterator)
# --> 127 processed = self.infer(item, **self.params)
#     128 # We now have a batch of "inferred things".
#     129 if self.loader_batch_size is not None:
#     130     # Try to infer the size of the batch
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/transformers/pipelines/base.py:1374, in Pipeline.forward(self, model_inputs, **forward_params)
#    1372     with inference_context():
#    1373         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1374         model_outputs = self._forward(model_inputs, **forward_params)
#    1375         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1376 else:
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/transformers/pipelines/text_generation.py:432, in TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     429 if "generation_config" not in generate_kwargs:
#     430     generate_kwargs["generation_config"] = self.generation_config
# --> 432 output = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     434 if isinstance(output, ModelOutput):
#     435     generated_sequence = output.sequences
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/peft/peft_model.py:1973, in PeftModelForCausalLM.generate(self, *args, **kwargs)
#    1971     with self._enable_peft_forward_hooks(*args, **kwargs):
#    1972         kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 1973         outputs = self.base_model.generate(*args, **kwargs)
#    1974 else:
#    1975     outputs = self.base_model.generate(**kwargs)
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/transformers/generation/utils.py:2539, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2528     return GenerationMixin.generate(
#    2529         self,
#    2530         inputs,
#    (...)   2534         **kwargs,
#    2535     )
#    2537 elif generation_mode in (GenerationMode.SAMPLE, GenerationMode.GREEDY_SEARCH):
#    2538     # 11. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2539     result = self._sample(
#    2540         input_ids,
#    2541         logits_processor=prepared_logits_processor,
#    2542         stopping_criteria=prepared_stopping_criteria,
#    2543         generation_config=generation_config,
#    2544         synced_gpus=synced_gpus,
#    2545         streamer=streamer,
#    2546         **model_kwargs,
#    2547     )
#    2549 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2550     # 11. run beam sample
#    2551     result = self._beam_search(
#    2552         input_ids,
#    2553         logits_processor=prepared_logits_processor,
#    (...)   2557         **model_kwargs,
#    2558     )
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/transformers/generation/utils.py:2870, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2868     is_prefill = False
#    2869 else:
# -> 2870     outputs = model_forward(**model_inputs, return_dict=True)
#    2872 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    2873 model_kwargs = self._update_model_kwargs_for_generation(
#    2874     outputs,
#    2875     model_kwargs,
#    2876     is_encoder_decoder=self.config.is_encoder_decoder,
#    2877 )
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/transformers/utils/generic.py:940, in can_return_tuple.<locals>.wrapper(self, *args, **kwargs)
#     938 if return_dict_passed is not None:
#     939     return_dict = return_dict_passed
# --> 940 output = func(self, *args, **kwargs)
#     941 if not return_dict and not isinstance(output, tuple):
#     942     output = output.to_tuple()
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/transformers/models/qwen3/modeling_qwen3.py:480, in Qwen3ForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, cache_position, logits_to_keep, **kwargs)
#     443 @can_return_tuple
#     444 @auto_docstring
#     445 def forward(
#    (...)    456     **kwargs: Unpack[TransformersKwargs],
#     457 ) -> CausalLMOutputWithPast:
#     458     r"""
#     459     labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#     460         Labels for computing the masked language modeling loss. Indices should either be in `[0, ...,
#    (...)    478     "Hey, are you conscious? Can you talk to me?\nI'm not conscious, but I can talk to you."
#     479     ```"""
# --> 480     outputs: BaseModelOutputWithPast = self.model(
#     481         input_ids=input_ids,
#     482         attention_mask=attention_mask,
#     483         position_ids=position_ids,
#     484         past_key_values=past_key_values,
#     485         inputs_embeds=inputs_embeds,
#     486         use_cache=use_cache,
#     487         cache_position=cache_position,
#     488         **kwargs,
#     489     )
#     491     hidden_states = outputs.last_hidden_state
#     492     # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/transformers/utils/generic.py:1064, in check_model_inputs.<locals>.wrapper(self, *args, **kwargs)
#    1061                 module.forward = make_capture_wrapper(module, original_forward, key, specs.index)
#    1062                 monkey_patched_layers.append((module, original_forward))
# -> 1064 outputs = func(self, *args, **kwargs)
#    1065 # Restore original forward methods
#    1066 for module, original_forward in monkey_patched_layers:
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/transformers/models/qwen3/modeling_qwen3.py:410, in Qwen3Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, cache_position, **kwargs)
#     407 position_embeddings = self.rotary_emb(hidden_states, position_ids)
#     409 for decoder_layer in self.layers[: self.config.num_hidden_layers]:
# --> 410     hidden_states = decoder_layer(
#     411         hidden_states,
#     412         attention_mask=causal_mask_mapping[decoder_layer.attention_type],
#     413         position_ids=position_ids,
#     414         past_key_values=past_key_values,
#     415         use_cache=use_cache,
#     416         cache_position=cache_position,
#     417         position_embeddings=position_embeddings,
#     418         **kwargs,
#     419     )
#     421 hidden_states = self.norm(hidden_states)
#     422 return BaseModelOutputWithPast(
#     423     last_hidden_state=hidden_states,
#     424     past_key_values=past_key_values if use_cache else None,
#     425 )
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/transformers/modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning_once(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/transformers/utils/deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/transformers/models/qwen3/modeling_qwen3.py:260, in Qwen3DecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_values, use_cache, cache_position, position_embeddings, **kwargs)
#     258 hidden_states = self.input_layernorm(hidden_states)
#     259 # Self Attention
# --> 260 hidden_states, _ = self.self_attn(
#     261     hidden_states=hidden_states,
#     262     attention_mask=attention_mask,
#     263     position_ids=position_ids,
#     264     past_key_values=past_key_values,
#     265     use_cache=use_cache,
#     266     cache_position=cache_position,
#     267     position_embeddings=position_embeddings,
#     268     **kwargs,
#     269 )
#     270 hidden_states = residual + hidden_states
#     272 # Fully Connected
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/transformers/utils/deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/transformers/models/qwen3/modeling_qwen3.py:205, in Qwen3Attention.forward(self, hidden_states, position_embeddings, attention_mask, past_key_values, cache_position, **kwargs)
#     202 value_states = self.v_proj(hidden_states).view(hidden_shape).transpose(1, 2)
#     204 cos, sin = position_embeddings
# --> 205 query_states, key_states = apply_rotary_pos_emb(query_states, key_states, cos, sin)
#     207 if past_key_values is not None:
#     208     # sin and cos are specific to RoPE models; cache_position needed for the static cache
#     209     cache_kwargs = {"sin": sin, "cos": cos, "cache_position": cache_position}
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/transformers/models/qwen3/modeling_qwen3.py:115, in apply_rotary_pos_emb(q, k, cos, sin, position_ids, unsqueeze_dim)
#     113 cos = cos.unsqueeze(unsqueeze_dim)
#     114 sin = sin.unsqueeze(unsqueeze_dim)
# --> 115 q_embed = (q * cos) + (rotate_half(q) * sin)
#     116 k_embed = (k * cos) + (rotate_half(k) * sin)
#     117 return q_embed, k_embed
#
# File ~/kaia_exps/.venv/lib/python3.12/site-packages/transformers/models/qwen3/modeling_qwen3.py:90, in rotate_half(x)
#      88 x1 = x[..., : x.shape[-1] // 2]
#      89 x2 = x[..., x.shape[-1] // 2 :]
# ---> 90 return torch.cat((-x2, x1), dim=-1)
#
# KeyboardInterrupt:

# %%
# %cat eval.log
# Out:
# Mismatch:
# USER:I had a slice of quiche with 100g of mixed greens and a serving of 200ml of iced tea.
# LIST_LENGTH:3
# [1]FOOD:quiche,UNIT:slice,QUANTITY:1
# [2]FOOD:mixed greens,UNIT:gram,QUANTITY:100
# [3]FOOD:iced tea,UNIT:milliliter,QUANTITY:200 ->
# USER:I had a slice of quiche with 100g of mixed greens and a serving of 200ml of iced tea.
# :FOOD:quiche,UNIT:slice,QUANTITY:1
# :FOOD:mixed greens,UNIT:gram,QUANTITY:100
# :FOOD:iced tea,UNIT:milliliter,QUANTITY:200
# [1]FOOD:quiche,UNIT:slice,QUANTITY:1
# [2]FOOD:mixed greens,UNIT:gram,QUANTITY:100
# [3]FOOD:iced tea,UNIT:milliliter,QUANTITY:200
#
# Mismatch:
# USER:200g of  Sundubu Jjigae, a piece of  grilled mackerel, 100g of  bean sprouts, and 200ml of  Sujeonggwa.
# LIST_LENGTH:4
# [1]FOOD:Sundubu Jjigae,UNIT:gram,QUANTITY:200
# [2]FOOD:grilled mackerel,UNIT:piece,QUANTITY:1
# [3]FOOD:bean sprouts,UNIT:gram,QUANTITY:100
# [4]FOOD:Sujeonggwa,UNIT:milliliter,QUANTITY:200 ->
# USER:200g of  Sundubu Jjigae, a piece of  grilled mackerel, 100g of  bean sprouts, and 200ml of  Sujeonggwa.
# ,LIST_LENGTH:4
# [1]FOOD:Sundubu Jjigae,UNIT:gram,QUANTITY:200
# [2]FOOD:bean sprouts,UNIT:gram,QUANTITY:100
# [3]FOOD:Sujeonggwa,UNIT:milliliter,QUANTITY:200
# [4]FOOD:grilled mackerel,UNIT:piece,QUANTITY:1
#
# Mismatch:
# USER:Norwegian: 160g of  smalahove, 100g of  brunost, 140g of  fiskesuppe.
# LIST_LENGTH:3
# [1]FOOD:smalahove,UNIT:gram,QUANTITY:160
# [2]FOOD:brunost,UNIT:gram,QUANTITY:100
# [3]FOOD:fiskesuppe,UNIT:gram,QUANTITY:140 ->
# USER:Norwegian: 160g of  smalahove, 100g of  brunost, 140g of  fiskesuppe.
# wegian:160
# FOOD:smalahove,UNIT:gram,QUANTITY:1
# FOOD:brunost,UNIT:gram,QUANTITY:100
# FOOD:fiskesuppe,UNIT:gram,QUANTITY:140
# [1]FOOD:smalahove,UNIT:gram,QUANTITY:160
# [2]FOOD:brunost,UNIT:gram,QUANTITY:100
# [3]FOOD:fiskesuppe,UNIT:gram,QUANTITY:140
#
# Mismatch:
# USER:Breakfast: 150g Taho (Filipino), 200g  Mustikkapiirakka (Finnish), 150g Idli (Indian), 200g Jugo de Guayaba (Cuban), 1 apple.
# LIST_LENGTH:5
# [1]FOOD:Taho,UNIT:gram,QUANTITY:150
# [2]FOOD:Mustikkapiirakka,UNIT:gram,QUANTITY:200
# [3]FOOD:Idli,UNIT:gram,QUANTITY:150
# [4]FOOD:Jugo de Guayaba,UNIT:gram,QUANTITY:200
# [5]FOOD:apple,UNIT:piece,QUANTITY:1 ->
# USER:Breakfast: 150g Taho (Filipino), 200g  Mustikkapiirakka (Finnish), 150g Idli (Indian), 200g Jugo de Guayaba (Cuban), 1 apple.
# ,LIST_LENGTH:5
# [1]FOOD:Taho,UNIT:gram,QUANTITY:150
# [2]FOOD:Mustikkapiirakka,UNIT:gram,QUANTITY:200
# [3]FOOD:Idli,UNIT:gram,QUANTITY:150
# [4]FOOD:Jugo de Guayaba,UNIT:gram,QUANTITY:200
# [5]FOOD:apple,UNIT:piece,QUANTITY:1
#
# Mismatch:
# USER:Enjoyed 200g of tagine with chicken and a side of 150g of couscous salad.
# LIST_LENGTH:2
# [1]FOOD:tagine with chicken,UNIT:gram,QUANTITY:200
# [2]FOOD:couscous salad,UNIT:gram,QUANTITY:150 ->
# USER:Enjoyed 200g of tagine with chicken and a side of 150g of couscous salad.
# FOOD:tagine with chicken,UNIT:gram,QUANTITY:200
# LIST_LENGTH:2
# [1]FOOD:tagine with chicken,UNIT:gram,QUANTITY:200
# [2]FOOD:couscous salad,UNIT:gram,QUANTITY:150
#
# Mismatch:
# USER:I had 150g of pad thai, a spring roll, and a glass of Thai iced tea.
# LIST_LENGTH:3
# [1]FOOD:pad thai,UNIT:gram,QUANTITY:150
# [2]FOOD:spring roll,UNIT:piece,QUANTITY:1
# [3]FOOD:Thai iced tea,UNIT:glass,QUANTITY:1 ->
# USER:I had 150g of pad thai, a spring roll, and a glass of Thai iced tea.
# :FOOD:pad thai,UNIT:gram,QUANTITY:150
# :FOOD:spring roll,UNIT:piece,QUANTITY:1
# :FOOD:Thai iced tea,UNIT:glass,QUANTITY:1
#
# Mismatch:
# USER:Dinner: 200g of steak, 150g of baked beans, 100g of corn on the cob.
# LIST_LENGTH:3
# [1]FOOD:steak,UNIT:gram,QUANTITY:200
# [2]FOOD:baked beans,UNIT:gram,QUANTITY:150
# [3]FOOD:corn on the cob,UNIT:gram,QUANTITY:100 ->
# USER:Dinner: 200g of steak, 150g of baked beans, 100g of corn on the cob.
# FOOD:steak,UNIT:gram,QUANTITY:200
# FOOD:baked beans,UNIT:gram,QUANTITY:150
# FOOD:corn on the cob,UNIT:gram,QUANTITY:100
# LIST_LENGTH:3
# [1]FOOD:steak,UNIT:gram,QUANTITY:200
# [2]FOOD:baked beans,UNIT:gram,QUANTITY:150
# [3]FOOD:corn on the cob,UNIT:gram,QUANTITY:100
#
# Mismatch:
# USER:I enjoyed 200g of chicken tinga with 3 plates of pasta with gravy and 100g of queso fresco.
# LIST_LENGTH:3
# [1]FOOD:chicken tinga,UNIT:gram,QUANTITY:200
# [2]FOOD:pasta with gravy,UNIT:plate,QUANTITY:3
# [3]FOOD:queso fresco,UNIT:gram,QUANTITY:100 ->
# USER:I enjoyed 200g of chicken tinga with 3 plates of pasta with gravy and 100g of queso fresco.
# FOOD:chicken tinga,UNIT:gram,QUANTITY:200
# FOOD:pasta with gravy,UNIT:plate,QUANTITY:3
# FOOD:queso fresco,UNIT:gram,QUANTITY:100
# LIST_LENGTH:4
# [1]FOOD:chicken tinga,UNIT:gram,QUANTITY:200
# [2]FOOD:pasta with gravy,UNIT:plate,QUANTITY:3
# [3]FOOD:queso fresco,UNIT:gram,QUANTITY:100
# [4]FOOD:FOOD,UNIT:piece,QUANTITY:1
#
# Mismatch:
# USER:I made a smoothie with 150g of spinach, 200ml of coconut milk, and 30g of protein powder.
# LIST_LENGTH:3
# [1]FOOD:spinach,UNIT:gram,QUANTITY:150
# [2]FOOD:coconut milk,UNIT:milliliter,QUANTITY:200
# [3]FOOD:protein powder,UNIT:gram,QUANTITY:30 ->
# USER:I made a smoothie with 150g of spinach, 200ml of coconut milk, and 30g of protein powder.
# :FOOD:spinach,UNIT:gram,QUANTITY:150
# :FOOD:coconut milk,UNIT:milliliter,QUANTITY:200
# :FOOD:protein powder,UNIT:gram,QUANTITY:30
# LIST_LENGTH:3
# [1]FOOD:spinach,UNIT:gram,QUANTITY:150
# [2]FOOD:coconut milk,UNIT:milliliter,QUANTITY:200
# [3]FOOD:protein powder,UNIT:gram,QUANTITY:30
#
# Mismatch:
# USER:I had 2 pancakes, 100g of maple syrup, 50g of blueberries, and a side of bacon.
# LIST_LENGTH:4
# [1]FOOD:pancakes,UNIT:piece,QUANTITY:2
# [2]FOOD:maple syrup,UNIT:gram,QUANTITY:100
# [3]FOOD:blueberries,UNIT:gram,QUANTITY:50
# [4]FOOD:bacon,UNIT:side,QUANTITY:1 ->
# USER:I had 2 pancakes, 100g of maple syrup, 50g of blueberries, and a side of bacon.
# FOOD:pancakes,UNIT:piece,QUANTITY:2
# FOOD:maple syrup,UNIT:gram,QUANTITY:100
# FOOD:blueberries,UNIT:gram,QUANTITY:50
# FOOD:bacon,UNIT:side,QUANTITY:1
#
# Mismatch:
# USER:100g of  Kimchi Fried Rice, 150g of  Dubu Jorim, 70g of  cucumber kimchi, and a bowl of rice.
# LIST_LENGTH:4
# [1]FOOD:Kimchi Fried Rice,UNIT:gram,QUANTITY:100
# [2]FOOD:Dubu Jorim,UNIT:gram,QUANTITY:150
# [3]FOOD:cucumber kimchi,UNIT:gram,QUANTITY:70
# [4]FOOD:rice,UNIT:bowl,QUANTITY:1 ->
# USER:100g of  Kimchi Fried Rice, 150g of  Dubu Jorim, 70g of  cucumber kimchi, and a bowl of rice.
# :FOOD:Kimchi Fried Rice,UNIT:gram,QUANTITY:100
# :FOOD:Dubu Jorim,UNIT:gram,QUANTITY:150
# :FOOD:cucumber kimchi,UNIT:gram,QUANTITY:70
# :FOOD:rice,UNIT:bowl,QUANTITY:1
#
# Mismatch:
# USER:Snack: 160g of panna cotta, 90g of mixed berry jam, 100g of cream cheese spread.
# LIST_LENGTH:3
# [1]FOOD:panna cotta,UNIT:gram,QUANTITY:160
# [2]FOOD:mixed berry jam,UNIT:gram,QUANTITY:90
# [3]FOOD:cream cheese spread,UNIT:gram,QUANTITY:100 ->
# USER:Snack: 160g of panna cotta, 90g of mixed berry jam, 100g of cream cheese spread.
#
# [1]FOOD:panna cotta,UNIT:gram,QUANTITY:160
# [2]FOOD:mixed berry jam,UNIT:gram,QUANTITY:90
# [3]FOOD:cream cheese spread,UNIT:gram,QUANTITY:100
#
# Mismatch:
# USER:Enjoyed 1 bowl of congee, 2 pieces of dim sum, a side of pickled vegetables, and a cup of oolong tea.
# LIST_LENGTH:4
# [1]FOOD:congee,UNIT:bowl,QUANTITY:1
# [2]FOOD:dim sum,UNIT:piece,QUANTITY:2
# [3]FOOD:pickled vegetables,UNIT:side,QUANTITY:1
# [4]FOOD:oolong tea,UNIT:cup,QUANTITY:1 ->
# USER:Enjoyed 1 bowl of congee, 2 pieces of dim sum, a side of pickled vegetables, and a cup of oolong tea.
# ,LIST_LENGTH:4
# [1]FOOD:congee,UNIT:bowl,QUANTITY:1
# [2]FOOD:dim sum,UNIT:piece,QUANTITY:2
# [3]FOOD:pickled vegetables,UNIT:side,QUANTITY:1
# [4]FOOD:oolong tea,UNIT:cup,QUANTITY:1
#
# Mismatch:
# USER:For a light dinner, I had two spicy tuna rolls and a glass of lemon-blackberry sparkling lambrusco and gin.
# LIST_LENGTH:2
# [1]FOOD:spicy tuna rolls,UNIT:piece,QUANTITY:2
# [2]FOOD:lemon-blackberry sparkling lambrusco and gin,UNIT:glass,QUANTITY:1 ->
# USER:For a light dinner, I had two spicy tuna rolls and a glass of lemon-blackberry sparkling lambrusco and gin.
# ,LIST_LENGTH:2
# [1]FOOD:spicy tuna rolls,UNIT:piece,QUANTITY:2
# [2]FOOD:lemon-blackberry sparkling lambrusco and gin,UNIT:glass,QUANTITY:1
#
# Mismatch:
# USER:Treats: 150g of sweet rice pudding, 130g of orange blossom cake, 100g of chocolate mousse.
# LIST_LENGTH:3
# [1]FOOD:sweet rice pudding,UNIT:gram,QUANTITY:150
# [2]FOOD:orange blossom cake,UNIT:gram,QUANTITY:130
# [3]FOOD:chocolate mousse,UNIT:gram,QUANTITY:100 ->
# USER:Treats: 150g of sweet rice pudding, 130g of orange blossom cake, 100g of chocolate mousse.
# :FOOD:sweet rice pudding,UNIT:gram,QUANTITY:150
# :FOOD:orange blossom cake,UNIT:gram,QUANTITY:130
# :FOOD:chocolate mousse,UNIT:gram,QUANTITY:100
# [1]FOOD:sweet rice pudding,UNIT:gram,QUANTITY:150
# [2]FOOD:orange blossom cake,UNIT:gram,QUANTITY:130
# [3]FOOD:chocolate mousse,UNIT:gram,QUANTITY:100
#
# Mismatch:
# USER:I had a savory pancake made from 100g of chickpea flour topped with 50g of avocado and 1 tablespoon of chili sauce.
# LIST_LENGTH:3
# [1]FOOD:chickpea flour,UNIT:gram,QUANTITY:100
# [2]FOOD:avocado,UNIT:gram,QUANTITY:50
# [3]FOOD:chili sauce,UNIT:tablespoon,QUANTITY:1 ->
# USER:I had a savory pancake made from 100g of chickpea flour topped with 50g of avocado and 1 tablespoon of chili sauce.
# FOOD:chickpea flour,UNIT:gram,QUANTITY:100
# FOOD:avocado,UNIT:gram,QUANTITY:50
# FOOD:chili sauce,UNIT:tablespoon,QUANTITY:1
#
# Mismatch:
# USER:Had 200g of pho ga with 50g of chicken and a side of basil leaves.
# LIST_LENGTH:3
# [1]FOOD:pho ga,UNIT:gram,QUANTITY:200
# [2]FOOD:chicken,UNIT:gram,QUANTITY:50
# [3]FOOD:basil leaves,UNIT:side,QUANTITY:1 ->
# USER:Had 200g of pho ga with 50g of chicken and a side of basil leaves.
# FOOD:pho ga,UNIT:gram,QUANTITY:200
# LIST_LENGTH:3
# [1]FOOD:pho ga,UNIT:gram,QUANTITY:200
# [2]FOOD:chicken,UNIT:gram,QUANTITY:50
# [3]FOOD:basil leaves,UNIT:side,QUANTITY:1
#
# Mismatch:
# USER:I had 150g of  ice cream, 75g of chocolate syrup, 2 wafers, and a cherry.
# LIST_LENGTH:4
# [1]FOOD:ice cream,UNIT:gram,QUANTITY:150
# [2]FOOD:chocolate syrup,UNIT:gram,QUANTITY:75
# [3]FOOD:wafers,UNIT:piece,QUANTITY:2
# [4]FOOD:cherry,UNIT:piece,QUANTITY:1 ->
# USER:I had 150g of  ice cream, 75g of chocolate syrup, 2 wafers, and a cherry.
# FOOD:ice cream,UNIT:gram,QUANTITY:150
# FOOD:chocolate syrup,UNIT:gram,QUANTITY:75
# FOOD:wafers,UNIT:piece,QUANTITY:2
# FOOD:cherry,UNIT:piece,QUANTITY:1
#
# Mismatch:
# USER:I had 200g of pierogi, 100g of sour cream, 50g of fried onions and a glass of kvass.
# LIST_LENGTH:4
# [1]FOOD:pierogi,UNIT:gram,QUANTITY:200
# [2]FOOD:sour cream,UNIT:gram,QUANTITY:100
# [3]FOOD:fried onions,UNIT:gram,QUANTITY:50
# [4]FOOD:kvass,UNIT:glass,QUANTITY:1 ->
# USER:I had 200g of pierogi, 100g of sour cream, 50g of fried onions and a glass of kvass.
# :FOOD:pierogi,UNIT:gram,QUANTITY:200
# :FOOD:sour cream,UNIT:gram,QUANTITY:100
# :FOOD:fried onions,UNIT:gram,QUANTITY:50
# :FOOD:kvass,UNIT:glass,QUANTITY:1
#
# Mismatch:
# USER:180g of  Bulgogi, 100g of  potato salad, 200g of  noodles, and a banana.
# LIST_LENGTH:4
# [1]FOOD:Bulgogi,UNIT:gram,QUANTITY:180
# [2]FOOD:potato salad,UNIT:gram,QUANTITY:100
# [3]FOOD:noodles,UNIT:gram,QUANTITY:200
# [4]FOOD:banana,UNIT:piece,QUANTITY:1 ->
# USER:180g of  Bulgogi, 100g of  potato salad, 200g of  noodles, and a banana.
# FOOD:Bulgogi,UNIT:gram,QUANTITY:180
# FOOD:potato salad,UNIT:gram,QUANTITY:100
# FOOD:noodles,UNIT:gram,QUANTITY:200
# FOOD:banana,UNIT:piece,QUANTITY:1
#
# Mismatch:
# USER:Breakfast: 100g of  Puto Maya, 2  eggs, 100g of  Banana.
# LIST_LENGTH:3
# [1]FOOD:Puto Maya,UNIT:gram,QUANTITY:100
# [2]FOOD:eggs,UNIT:piece,QUANTITY:2
# [3]FOOD:Banana,UNIT:gram,QUANTITY:100 ->
# USER:Breakfast: 100g of  Puto Maya, 2  eggs, 100g of  Banana.
# :FOOD:Puto Maya,UNIT:gram,QUANTITY:100
# :FOOD:eggs,UNIT:piece,QUANTITY:2
# :FOOD:Banana,UNIT:gram,QUANTITY:100
# LIST_LENGTH:3
# [1]FOOD:Puto Maya,UNIT:gram,QUANTITY:100
# [2]FOOD:eggs,UNIT:piece,QUANTITY:2
# [3]FOOD:Banana,UNIT:gram,QUANTITY:100
#
# Mismatch:
# USER:Dinner: 250g of chicken in cream sauce, 200g of beetroot salad with yogurt, 150g of raspberry vinaigrette.
# LIST_LENGTH:3
# [1]FOOD:chicken in cream sauce,UNIT:gram,QUANTITY:250
# [2]FOOD:beetroot salad with yogurt,UNIT:gram,QUANTITY:200
# [3]FOOD:raspberry vinaigrette,UNIT:gram,QUANTITY:150 ->
# USER:Dinner: 250g of chicken in cream sauce, 200g of beetroot salad with yogurt, 150g of raspberry vinaigrette.
#
# LIST_LENGTH:3
# [1]FOOD:chicken in cream sauce,UNIT:gram,QUANTITY:250
# [2]FOOD:beetroot salad with yogurt,UNIT:gram,QUANTITY:200
# [3]FOOD:raspberry vinaigrette,UNIT:gram,QUANTITY:150
#
# Mismatch:
# USER:Lunch: 250g of mujaddara, 150g of tabbouleh, 180g of stuffed grape leaves.
# LIST_LENGTH:3
# [1]FOOD:mujaddara,UNIT:gram,QUANTITY:250
# [2]FOOD:tabbouleh,UNIT:gram,QUANTITY:150
# [3]FOOD:stuffed grape leaves,UNIT:gram,QUANTITY:180 ->
# USER:Lunch: 250g of mujaddara, 150g of tabbouleh, 180g of stuffed grape leaves.
# :FOOD:mujaddara,UNIT:gram,QUANTITY:250
# :FOOD:tabbouleh,UNIT:gram,QUANTITY:150
# :FOOD:stuffed grape leaves,UNIT:gram,QUANTITY:180
# LIST_LENGTH:3
# [1]FOOD:mujaddara,UNIT:gram,QUANTITY:250
# [2]FOOD:tabbouleh,UNIT:gram,QUANTITY:150
# [3]FOOD:stuffed grape leaves,UNIT:gram,QUANTITY:180
#
# Mismatch:
# USER:Dinner: 250g of Sinigang, 100g of steamed rice, 50g of Kangkong.
# LIST_LENGTH:3
# [1]FOOD:Sinigang,UNIT:gram,QUANTITY:250
# [2]FOOD:steamed rice,UNIT:gram,QUANTITY:100
# [3]FOOD:Kangkong,UNIT:gram,QUANTITY:50 ->
# USER:Dinner: 250g of Sinigang, 100g of steamed rice, 50g of Kangkong.
# ,LIST_LENGTH:3
# [1]FOOD:Sinigang,UNIT:gram,QUANTITY:250
# [2]FOOD:steamed rice,UNIT:gram,QUANTITY:100
# [3]FOOD:Kangkong,UNIT:gram,QUANTITY:50
#
# Mismatch:
# USER:I had 300g of seafood salad with 50g of avocado and a wedge of lime.
# LIST_LENGTH:3
# [1]FOOD:seafood salad,UNIT:gram,QUANTITY:300
# [2]FOOD:avocado,UNIT:gram,QUANTITY:50
# [3]FOOD:lime wedge,UNIT:piece,QUANTITY:1 ->
# USER:I had 300g of seafood salad with 50g of avocado and a wedge of lime.
# :FOOD:seafood salad,UNIT:gram,QUANTITY:300
# :FOOD:avocado,UNIT:gram,QUANTITY:50
# :FOOD:lime wedge,UNIT:piece,QUANTITY:1
#
# Mismatch:
# USER:Ate 150g of bacalao a la vizcaína with 100g of potatoes.
# LIST_LENGTH:2
# [1]FOOD:bacalao a la vizcaína,UNIT:gram,QUANTITY:150
# [2]FOOD:potatoes,UNIT:gram,QUANTITY:100 ->
# USER:Ate 150g of bacalao a la vizcaína with 100g of potatoes.
# :FOOD:bacalao a la vizcaína,UNIT:gram,QUANTITY:150
# LIST_LENGTH:2
# [1]FOOD:bacalao a la vizcaína,UNIT:gram,QUANTITY:150
# [2]FOOD:potatoes,UNIT:gram,QUANTITY:100
#
# Mismatch:
# USER:Enjoyed 1 cup of oatmeal, 50g of raisins, a handful of pecans, and a glass of fresh grape juice.
# LIST_LENGTH:4
# [1]FOOD:oatmeal,UNIT:cup,QUANTITY:1
# [2]FOOD:raisins,UNIT:gram,QUANTITY:50
# [3]FOOD:pecans,UNIT:handful,QUANTITY:1
# [4]FOOD:fresh grape juice,UNIT:glass,QUANTITY:1 ->
# USER:Enjoyed 1 cup of oatmeal, 50g of raisins, a handful of pecans, and a glass of fresh grape juice.
#
# LIST_LENGTH:4
# [1]FOOD:oatmeal,UNIT:cup,QUANTITY:1
# [2]FOOD:raisins,UNIT:gram,QUANTITY:50
# [3]FOOD:pecans,UNIT:handful,QUANTITY:1
# [4]FOOD:fresh grape juice,UNIT:glass,QUANTITY:1
#
# Mismatch:
# USER:Enjoyed 200g of  jambalaya with 100g of  dirty rice.
# LIST_LENGTH:2
# [1]FOOD:jambalaya,UNIT:gram,QUANTITY:200
# [2]FOOD:dirty rice,UNIT:gram,QUANTITY:100 ->
# USER:Enjoyed 200g of  jambalaya with 100g of  dirty rice.
# FOOD:jambalaya,UNIT:gram,QUANTITY:200
# LIST_LENGTH:2
# [1]FOOD:jambalaya,UNIT:gram,QUANTITY:200
# [2]FOOD:dirty rice,UNIT:gram,QUANTITY:100
#
# Mismatch:
# USER:I enjoyed a serving of 300ml of green tea with 2 slices of toast and 30g of butter.
# LIST_LENGTH:3
# [1]FOOD:green tea,UNIT:milliliter,QUANTITY:300
# [2]FOOD:toast,UNIT:slice,QUANTITY:2
# [3]FOOD:butter,UNIT:gram,QUANTITY:30 ->
# USER:I enjoyed a serving of 300ml of green tea with 2 slices of toast and 30g of butter.
# FOOD:green tea,UNIT:milliliter,QUANTITY:300
# LIST_LENGTH:3
# [1]FOOD:toast,UNIT:slice,QUANTITY:2
# [2]FOOD:butter,UNIT:gram,QUANTITY:30
# [3]FOOD:green tea,UNIT:milliliter,QUANTITY:300
#
# Mismatch:
# USER:I sampled 150g of cheese fondue with 5 pieces of bread and 1 glass of champagne.
# LIST_LENGTH:3
# [1]FOOD:cheese fondue,UNIT:gram,QUANTITY:150
# [2]FOOD:bread,UNIT:piece,QUANTITY:5
# [3]FOOD:champagne,UNIT:glass,QUANTITY:1 ->
# USER:I sampled 150g of cheese fondue with 5 pieces of bread and 1 glass of champagne.
# FOOD:cheese fondue,UNIT:gram,QUANTITY:150
# LIST_LENGTH:3
# [1]FOOD:cheese fondue,UNIT:gram,QUANTITY:150
# [2]FOOD:bread,UNIT:piece,QUANTITY:5
# [3]FOOD:champagne,UNIT:glass,QUANTITY:1
#
# Mismatch:
# USER:I ate 2 tostadas with 100g of beans, 50g of cheese, and a  jícama.
# LIST_LENGTH:3
# [1]FOOD:beans,UNIT:gram,QUANTITY:100
# [2]FOOD:cheese,UNIT:gram,QUANTITY:50
# [3]FOOD:jícama,UNIT:piece,QUANTITY:1 ->
# USER:I ate 2 tostadas with 100g of beans, 50g of cheese, and a  jícama.
# :FOOD:tostadas,UNIT:piece,QUANTITY:2
# :FOOD:beans,UNIT:gram,QUANTITY:100
# :FOOD:cheese,UNIT:gram,QUANTITY:50
# :FOOD:jícama,UNIT:piece,QUANTITY:1
#
# Mismatch:
# USER:Consumed 150g of quinoa, 100g of grilled chicken breast, a side of steamed broccoli, and a glass of protein shake.
# LIST_LENGTH:4
# [1]FOOD:quinoa,UNIT:gram,QUANTITY:150
# [2]FOOD:grilled chicken breast,UNIT:gram,QUANTITY:100
# [3]FOOD:steamed broccoli,UNIT:side,QUANTITY:1
# [4]FOOD:protein shake,UNIT:glass,QUANTITY:1 ->
# USER:Consumed 150g of quinoa, 100g of grilled chicken breast, a side of steamed broccoli, and a glass of protein shake.
# FOOD:quinoa,UNIT:gram,QUANTITY:150
# FOOD:grilled chicken breast,UNIT:gram,QUANTITY:100
# FOOD:steamed broccoli,UNIT:side,QUANTITY:1
# FOOD:protein shake,UNIT:glass,QUANTITY:1
#
# Mismatch:
# USER:My lunch included 150g of tofu, 100g of edamame, 30g of sesame oil, and a bowl of miso soup.
# LIST_LENGTH:4
# [1]FOOD:tofu,UNIT:gram,QUANTITY:150
# [2]FOOD:edamame,UNIT:gram,QUANTITY:100
# [3]FOOD:sesame oil,UNIT:gram,QUANTITY:30
# [4]FOOD:miso soup,UNIT:bowl,QUANTITY:1 ->
# USER:My lunch included 150g of tofu, 100g of edamame, 30g of sesame oil, and a bowl of miso soup.
# ,LIST_LENGTH:4
# [1]FOOD:tofu,UNIT:gram,QUANTITY:150
# [2]FOOD:edamame,UNIT:gram,QUANTITY:100
# [3]FOOD:sesame oil,UNIT:gram,QUANTITY:30
# [4]FOOD:miso soup,UNIT:bowl,QUANTITY:1
#
# Mismatch:
# USER:Lunch: 240g of jellied fish with yogurt, 180g of coleslaw, 160g of olive tapenade.
# LIST_LENGTH:3
# [1]FOOD:jellied fish with yogurt,UNIT:gram,QUANTITY:240
# [2]FOOD:coleslaw,UNIT:gram,QUANTITY:180
# [3]FOOD:olive tapenade,UNIT:gram,QUANTITY:160 ->
# USER:Lunch: 240g of jellied fish with yogurt, 180g of coleslaw, 160g of olive tapenade.
#
# LIST_LENGTH:3
# [1]FOOD:jellied fish with yogurt,UNIT:gram,QUANTITY:240
# [2]FOOD:coleslaw,UNIT:gram,QUANTITY:180
# [3]FOOD:olive tapenade,UNIT:gram,QUANTITY:160
#
# Mismatch:
# USER:Had 1 bowl of 200g of quinoa with 100g of black beans and 1 tablespoon of salsa.
# LIST_LENGTH:3
# [1]FOOD:quinoa,UNIT:gram,QUANTITY:200
# [2]FOOD:black beans,UNIT:gram,QUANTITY:100
# [3]FOOD:salsa,UNIT:tablespoon,QUANTITY:1 ->
# USER:Had 1 bowl of 200g of quinoa with 100g of black beans and 1 tablespoon of salsa.
#   LIST_LENGTH:3
# [1]FOOD:quinoa,UNIT:gram,QUANTITY:200
# [2]FOOD:black beans,UNIT:gram,QUANTITY:100
# [3]FOOD:salsa,UNIT:tablespoon,QUANTITY:1
#
# Mismatch:
# USER:Treats: 150g  Turon (Filipino), 70g  Runebergintorttu (Finnish), 100g  Kheer (Indian), 150g  Quesillo (Cuban), 150ml  Orange Juice (Finnish).
# LIST_LENGTH:5
# [1]FOOD:Turon,UNIT:gram,QUANTITY:150
# [2]FOOD:Runebergintorttu,UNIT:gram,QUANTITY:70
# [3]FOOD:Kheer,UNIT:gram,QUANTITY:100
# [4]FOOD:Quesillo,UNIT:gram,QUANTITY:150
# [5]FOOD:Orange Juice,UNIT:milliliter,QUANTITY:150 ->
# USER:Treats: 150g  Turon (Filipino), 70g  Runebergintorttu (Finnish), 100g  Kheer (Indian), 150g  Quesillo (Cuban), 150ml  Orange Juice (Finnish).
# ,LIST_LENGTH:5
# [1]FOOD:Turon,UNIT:gram,QUANTITY:150
# [2]FOOD:Runebergintorttu,UNIT:gram,QUANTITY:70
# [3]FOOD:Kheer,UNIT:gram,QUANTITY:100
# [4]FOOD:Quesillo,UNIT:gram,QUANTITY:150
# [5]FOOD:Orange Juice,UNIT:milliliter,QUANTITY:150
#
# Mismatch:
# USER:Consumed 150g of vegetable curry, 100g of basmati rice, and a mango.
# LIST_LENGTH:3
# [1]FOOD:vegetable curry,UNIT:gram,QUANTITY:150
# [2]FOOD:basmati rice,UNIT:gram,QUANTITY:100
# [3]FOOD:mango,UNIT:piece,QUANTITY:1 ->
# USER:Consumed 150g of vegetable curry, 100g of basmati rice, and a mango.
# :FOOD:vegetable curry,UNIT:gram,QUANTITY:150
# :FOOD:basmati rice,UNIT:gram,QUANTITY:100
# :FOOD:mango,UNIT:piece,QUANTITY:1
# LIST_LENGTH:3
# [1]FOOD:vegetable curry,UNIT:gram,QUANTITY:150
# [2]FOOD:basmati rice,UNIT:gram,QUANTITY:100
# [3]FOOD:mango,UNIT:piece,QUANTITY:1
#
# Mismatch:
# USER:I had a serving of 300g of paella with 100g of shrimp and 50g of green peas.
# LIST_LENGTH:3
# [1]FOOD:paella,UNIT:gram,QUANTITY:300
# [2]FOOD:shrimp,UNIT:gram,QUANTITY:100
# [3]FOOD:green peas,UNIT:gram,QUANTITY:50 ->
# USER:I had a serving of 300g of paella with 100g of shrimp and 50g of green peas.
# :FOOD:paella,UNIT:gram,QUANTITY:300
# :FOOD:shrimp,UNIT:gram,QUANTITY:100
# :FOOD:green peas,UNIT:gram,QUANTITY:50
# [1]FOOD:paella,UNIT:gram,QUANTITY:300
# [2]FOOD:shrimp,UNIT:gram,QUANTITY:100
# [3]FOOD:green peas,UNIT:gram,QUANTITY:50
#
# Mismatch:
# USER:Breakfast: 170g of kashk-e bademjan, 110g of pita bread, 90g of olives.
# LIST_LENGTH:3
# [1]FOOD:kashk-e bademjan,UNIT:gram,QUANTITY:170
# [2]FOOD:pita bread,UNIT:gram,QUANTITY:110
# [3]FOOD:olives,UNIT:gram,QUANTITY:90 ->
# USER:Breakfast: 170g of kashk-e bademjan, 110g of pita bread, 90g of olives.
# ,LIST_LENGTH:3
# [1]FOOD:kashk-e bademjan,UNIT:gram,QUANTITY:170
# [2]FOOD:pita bread,UNIT:gram,QUANTITY:110
# [3]FOOD:olives,UNIT:gram,QUANTITY:90
#
# Mismatch:
# USER:Breakfast: 2 pieces of Champorado, 100g of Pan de Sal, 150ml of Tsokolate.
# LIST_LENGTH:3
# [1]FOOD:Champorado,UNIT:piece,QUANTITY:2
# [2]FOOD:Pan de Sal,UNIT:gram,QUANTITY:100
# [3]FOOD:Tsokolate,UNIT:milliliter,QUANTITY:150 ->
# USER:Breakfast: 2 pieces of Champorado, 100g of Pan de Sal, 150ml of Tsokolate.
# fast-forward
# LIST_LENGTH:3
# [1]FOOD:Champorado,UNIT:piece,QUANTITY:2
# [2]FOOD:Pan de Sal,UNIT:gram,QUANTITY:100
# [3]FOOD:Tsokolate,UNIT:milliliter,QUANTITY:150
#
# Mismatch:
# USER:I enjoyed 200g of beef tacos with 1 avocado and a third of a cup of cocoa.
# LIST_LENGTH:3
# [1]FOOD:beef tacos,UNIT:gram,QUANTITY:200
# [2]FOOD:avocado,UNIT:piece,QUANTITY:1
# [3]FOOD:cocoa,UNIT:cup,QUANTITY:0 ->
# USER:I enjoyed 200g of beef tacos with 1 avocado and a third of a cup of cocoa.
#  list_LENGTH:3
# [1]FOOD:beef tacos,UNIT:gram,QUANTITY:200
# [2]FOOD:avocado,UNIT:piece,QUANTITY:1
# [3]FOOD:cocoa,UNIT:cup,QUANTITY:0
#
# Mismatch:
# USER:Consumed 1 plate of spaghetti bolognese with 100g of meat sauce and a side of garlic bread.
# LIST_LENGTH:3
# [1]FOOD:spaghetti bolognese,UNIT:plate,QUANTITY:1
# [2]FOOD:meat sauce,UNIT:gram,QUANTITY:100
# [3]FOOD:garlic bread,UNIT:side,QUANTITY:1 ->
# USER:Consumed 1 plate of spaghetti bolognese with 100g of meat sauce and a side of garlic bread.
# ,FOOD:spaghetti bolognese,UNIT:plate,QUANTITY:1
# ,FOOD:meat sauce,UNIT:gram,QUANTITY:100
# ,FOOD:garlic bread,UNIT:side,QUANTITY:1
#
# Mismatch:
# USER:I enjoyed with two plates of risotto with asparagus with 100g of shrimp and half a handful of parsley.
# LIST_LENGTH:3
# [1]FOOD:risotto with asparagus,UNIT:plate,QUANTITY:2
# [2]FOOD:shrimp,UNIT:gram,QUANTITY:100
# [3]FOOD:parsley,UNIT:handful,QUANTITY:0 ->
# USER:I enjoyed with two plates of risotto with asparagus with 100g of shrimp and half a handful of parsley.
# FOOD:risotto with asparagus,UNIT:plate,QUANTITY:2
# FOOD:shrimp,UNIT:gram,QUANTITY:100
# FOOD:parsley,UNIT:handful,QUANTITY:0
# LIST_LENGTH:3
# [1]FOOD:risotto with asparagus,UNIT:plate,QUANTITY:2
# [2]FOOD:shrimp,UNIT:gram,QUANTITY:100
# [3]FOOD:parsley,UNIT:handful,QUANTITY:0
#
# Mismatch:
# USER:Had 100g of smoked turkey breast with 2 slices of multigrain bread and a handful of arugula.
# LIST_LENGTH:3
# [1]FOOD:smoked turkey breast,UNIT:gram,QUANTITY:100
# [2]FOOD:multigrain bread,UNIT:slice,QUANTITY:2
# [3]FOOD:arugula,UNIT:handful,QUANTITY:1 ->
# USER:Had 100g of smoked turkey breast with 2 slices of multigrain bread and a handful of arugula.
# ,LIST_LENGTH:3
# [1]FOOD:smoked turkey breast,UNIT:gram,QUANTITY:100
# [2]FOOD:multigrain bread,UNIT:slice,QUANTITY:2
# [3]FOOD:arugula,UNIT:handful,QUANTITY:1
#
# Mismatch:
# USER:Ate 150g of chicken salad with 100g of mixed vegetables and a serving of ranch dressing.
# LIST_LENGTH:3
# [1]FOOD:chicken salad,UNIT:gram,QUANTITY:150
# [2]FOOD:mixed vegetables,UNIT:gram,QUANTITY:100
# [3]FOOD:ranch dressing,UNIT:serving,QUANTITY:1 ->
# USER:Ate 150g of chicken salad with 100g of mixed vegetables and a serving of ranch dressing.
# :FOOD:chicken salad,UNIT:gram,QUANTITY:150
# :FOOD:mixed vegetables,UNIT:gram,QUANTITY:100
# :FOOD:ranch dressing,UNIT:serving,QUANTITY:1
#
# Mismatch:
# USER:I enjoyed 250g of chicken mole with 2 rice cakes and 60g of plantains.
# LIST_LENGTH:3
# [1]FOOD:chicken mole,UNIT:gram,QUANTITY:250
# [2]FOOD:rice cakes,UNIT:piece,QUANTITY:2
# [3]FOOD:plantains,UNIT:gram,QUANTITY:60 ->
# USER:I enjoyed 250g of chicken mole with 2 rice cakes and 60g of plantains.
# :FOOD:chicken mole,UNIT:gram,QUANTITY:250
# :FOOD:rice cakes,UNIT:piece,QUANTITY:2
# :FOOD:plantains,UNIT:gram,QUANTITY:60
# LIST_LENGTH:3
# [1]FOOD:chicken mole,UNIT:gram,QUANTITY:250
# [2]FOOD:rice cakes,UNIT:piece,QUANTITY:2
# [3]FOOD:plantains,UNIT:gram,QUANTITY:60
#
# Mismatch:
# USER:I ate 200g of japchae, 50g of beef, 25g of spinach, and 10g of sesame seeds.
# LIST_LENGTH:4
# [1]FOOD:japchae,UNIT:gram,QUANTITY:200
# [2]FOOD:beef,UNIT:gram,QUANTITY:50
# [3]FOOD:spinach,UNIT:gram,QUANTITY:25
# [4]FOOD:sesame seeds,UNIT:gram,QUANTITY:10 ->
# USER:I ate 200g of japchae, 50g of beef, 25g of spinach, and 10g of sesame seeds.
#
# LIST_LENGTH:4
# [1]FOOD:japchae,UNIT:gram,QUANTITY:200
# [2]FOOD:beef,UNIT:gram,QUANTITY:50
# [3]FOOD:spinach,UNIT:gram,QUANTITY:25
# [4]FOOD:sesame seeds,UNIT:gram,QUANTITY:10
#
# Mismatch:
# USER:Treats: 140g of berry gelatin, 120g of mascarpone cheese, 80g of blueberry tarts.
# LIST_LENGTH:3
# [1]FOOD:berry gelatin,UNIT:gram,QUANTITY:140
# [2]FOOD:mascarpone cheese,UNIT:gram,QUANTITY:120
# [3]FOOD:blueberry tarts,UNIT:gram,QUANTITY:80 ->
# USER:Treats: 140g of berry gelatin, 120g of mascarpone cheese, 80g of blueberry tarts.
# of:FOOD,UNIT:gram,QUANTITY:140
# [1]FOOD:berry gelatin,UNIT:gram,QUANTITY:140
# [2]FOOD:mascarpone cheese,UNIT:gram,QUANTITY:120
# [3]FOOD:blueberry tarts,UNIT:gram,QUANTITY:80
#
# Mismatch:
# USER:I had 150g of udon noodles, 100ml of dashi, 50g of shrimp, and a sheet of nori.
# LIST_LENGTH:4
# [1]FOOD:udon noodles,UNIT:gram,QUANTITY:150
# [2]FOOD:dashi,UNIT:milliliter,QUANTITY:100
# [3]FOOD:shrimp,UNIT:gram,QUANTITY:50
# [4]FOOD:nori sheet,UNIT:piece,QUANTITY:1 ->
# USER:I had 150g of udon noodles, 100ml of dashi, 50g of shrimp, and a sheet of nori.
# :FOOD:udon noodles,UNIT:gram,QUANTITY:150
# :FOOD:dashi,UNIT:milliliter,QUANTITY:100
# :FOOD:shrimp,UNIT:gram,QUANTITY:50
# :FOOD:nori,UNIT:sheet,QUANTITY:1
#
# Mismatch:
# USER:I enjoyed 50g of pistachios, 150g of sliced peaches, 100g of plain yogurt, and a nectarine.
# LIST_LENGTH:4
# [1]FOOD:pistachios,UNIT:gram,QUANTITY:50
# [2]FOOD:sliced peaches,UNIT:gram,QUANTITY:150
# [3]FOOD:plain yogurt,UNIT:gram,QUANTITY:100
# [4]FOOD:nectarine,UNIT:piece,QUANTITY:1 ->
# USER:I enjoyed 50g of pistachios, 150g of sliced peaches, 100g of plain yogurt, and a nectarine.
# FOOD:pistachios,UNIT:gram,QUANTITY:50
# FOOD:sliced peaches,UNIT:gram,QUANTITY:150
# FOOD:plain yogurt,UNIT:gram,QUANTITY:100
# FOOD:nectarine,UNIT:piece,QUANTITY:1
#
# Mismatch:
# USER:Had 300g of fried shrimp with 100g of cocktail sauce and a side of 1 corn on the cob.
# LIST_LENGTH:3
# [1]FOOD:fried shrimp,UNIT:gram,QUANTITY:300
# [2]FOOD:cocktail sauce,UNIT:gram,QUANTITY:100
# [3]FOOD:corn on the cob,UNIT:piece,QUANTITY:1 ->
# USER:Had 300g of fried shrimp with 100g of cocktail sauce and a side of 1 corn on the cob.
#   LIST_LENGTH:3
# [1]FOOD:fried shrimp,UNIT:gram,QUANTITY:300
# [2]FOOD:cocktail sauce,UNIT:gram,QUANTITY:100
# [3]FOOD:corn on the cob,UNIT:piece,QUANTITY:1
#
# Mismatch:
# USER:Enjoyed 150g of  escargots with a baguette and garlic butter.
# LIST_LENGTH:2
# [1]FOOD:escargots,UNIT:gram,QUANTITY:150
# [2]FOOD:baguette with garlic butter,UNIT:piece,QUANTITY:1 ->
# USER:Enjoyed 150g of  escargots with a baguette and garlic butter.
# FOOD:escargots,UNIT:gram,QUANTITY:150
# [FOOD:baguette,UNIT:piece,QUANTITY:1
# [FOOD:garlic butter,UNIT:piece,QUANTITY:1
#
# Mismatch:
# USER:I had 200g of  chilaquiles, 70g of  eggs, and 30g of  salsa.
# LIST_LENGTH:3
# [1]FOOD:chilaquiles,UNIT:gram,QUANTITY:200
# [2]FOOD:eggs,UNIT:gram,QUANTITY:70
# [3]FOOD:salsa,UNIT:gram,QUANTITY:30 ->
# USER:I had 200g of  chilaquiles, 70g of  eggs, and 30g of  salsa.
# :FOOD:chilaquiles,UNIT:gram,QUANTITY:200
# :FOOD:eggs,UNIT:gram,QUANTITY:70
# :FOOD:salsa,UNIT:gram,QUANTITY:30
# LIST_LENGTH:3
# [1]FOOD:chilaquiles,UNIT:gram,QUANTITY:200
# [2]FOOD:eggs,UNIT:gram,QUANTITY:70
# [3]FOOD:salsa,UNIT:gram,QUANTITY:30
#
# Mismatch:
# USER:I consumed 150g of vegetable kebab with 200g of couscous and a serving of harissa sauce.
# LIST_LENGTH:3
# [1]FOOD:vegetable kebab,UNIT:gram,QUANTITY:150
# [2]FOOD:couscous,UNIT:gram,QUANTITY:200
# [3]FOOD:harissa sauce,UNIT:serving,QUANTITY:1 ->
# USER:I consumed 150g of vegetable kebab with 200g of couscous and a serving of harissa sauce.
# :FOOD:vegetable kebab,UNIT:gram,QUANTITY:150
# :FOOD:couscous,UNIT:gram,QUANTITY:200
# :FOOD:harissa sauce,UNIT:serving,QUANTITY:1
# [1]FOOD:vegetable kebab,UNIT:gram,QUANTITY:150
# [2]FOOD:couscous,UNIT:gram,QUANTITY:200
# [3]FOOD:harissa sauce,UNIT:serving,QUANTITY:1
#
# Mismatch:
# USER:I had 180g of fish tacos with 1 lime and 30g of cabbage.
# LIST_LENGTH:3
# [1]FOOD:fish tacos,UNIT:gram,QUANTITY:180
# [2]FOOD:lime,UNIT:piece,QUANTITY:1
# [3]FOOD:cabbage,UNIT:gram,QUANTITY:30 ->
# USER:I had 180g of fish tacos with 1 lime and 30g of cabbage.
#
# LIST_LENGTH:3
# [1]FOOD:fish tacos,UNIT:gram,QUANTITY:180
# [2]FOOD:lime,UNIT:piece,QUANTITY:1
# [3]FOOD:cabbage,UNIT:gram,QUANTITY:30
#
# Mismatch:
# USER:Treats: 200g Cannoli (Italian), 150g Panna Cotta (Italian), 300g Cheesecake (American), 100g Churros (Spanish), 250ml Hot Chocolate (Mixed).
# LIST_LENGTH:5
# [1]FOOD:Cannoli,UNIT:gram,QUANTITY:200
# [2]FOOD:Panna Cotta,UNIT:gram,QUANTITY:150
# [3]FOOD:Cheesecake,UNIT:gram,QUANTITY:300
# [4]FOOD:Churros,UNIT:gram,QUANTITY:100
# [5]FOOD:Hot Chocolate,UNIT:milliliter,QUANTITY:250 ->
# USER:Treats: 200g Cannoli (Italian), 150g Panna Cotta (Italian), 300g Cheesecake (American), 100g Churros (Spanish), 250ml Hot Chocolate (Mixed).
# :FOOD:Cannoli,UNIT:gram,QUANTITY:200
# :FOOD:Panna Cotta,UNIT:gram,QUANTITY:150
# :FOOD:Cheesecake,UNIT:gram,QUANTITY:300
# :FOOD:Churros,UNIT:gram,QUANTITY:100
# :FOOD:Hot Chocolate,UNIT:milliliter,QUANTITY:250
#
# Mismatch:
# USER:For a refreshing lunch, I had a glass of strawberry iced tea and a bowl of ramen with chicken and teriyaki sauce.
# LIST_LENGTH:2
# [1]FOOD:strawberry iced tea,UNIT:glass,QUANTITY:1
# [2]FOOD:ramen with chicken and teriyaki sauce,UNIT:bowl,QUANTITY:1 ->
# USER:For a refreshing lunch, I had a glass of strawberry iced tea and a bowl of ramen with chicken and teriyaki sauce.
# FOOD:strawberry iced tea,UNIT:glass,QUANTITY:1
# LIST_LENGTH:2
# [1]FOOD:strawberry iced tea,UNIT:piece,QUANTITY:1
# [2]FOOD:ramen with chicken and teriyaki sauce,UNIT:bowl,QUANTITY:1
#
# Mismatch:
# USER:Snack: 130g of mixed fruit gelatin, 110g of lemon curd, 90g of shortbread cookies.
# LIST_LENGTH:3
# [1]FOOD:mixed fruit gelatin,UNIT:gram,QUANTITY:130
# [2]FOOD:lemon curd,UNIT:gram,QUANTITY:110
# [3]FOOD:shortbread cookies,UNIT:gram,QUANTITY:90 ->
# USER:Snack: 130g of mixed fruit gelatin, 110g of lemon curd, 90g of shortbread cookies.
# ,FOOD:mixed fruit gelatin,UNIT:gram,QUANTITY:130
# ,FOOD:lemon curd,UNIT:gram,QUANTITY:110
# ,FOOD:shortbread cookies,UNIT:gram,QUANTITY:90
# LIST_LENGTH:3
# [1]FOOD:mixed fruit gelatin,UNIT:gram,QUANTITY:130
# [2]FOOD:lemon curd,UNIT:gram,QUANTITY:110
# [3]FOOD:shortbread cookies,UNIT:gram,QUANTITY:90
#
# Mismatch:
# USER:Snack: 80g of  beijinho, 100g of  piernik, 90g of  cozonac.
# LIST_LENGTH:3
# [1]FOOD:beijinho,UNIT:gram,QUANTITY:80
# [2]FOOD:piernik,UNIT:gram,QUANTITY:100
# [3]FOOD:cozonac,UNIT:gram,QUANTITY:90 ->
# USER:Snack: 80g of  beijinho, 100g of  piernik, 90g of  cozonac.
# :LIST_LENGTH:3
# [1]FOOD:beijinho,UNIT:gram,QUANTITY:80
# [2]FOOD:piernik,UNIT:gram,QUANTITY:100
# [3]FOOD:cozonac,UNIT:gram,QUANTITY:90
#
# Mismatch:
# USER:Dinner: 220g of  churrasco, 200g of  gołąbki, 180g of  pui la rotisor.
# LIST_LENGTH:3
# [1]FOOD:churrasco,UNIT:gram,QUANTITY:220
# [2]FOOD:gołąbki,UNIT:gram,QUANTITY:200
# [3]FOOD:pui la rotisor,UNIT:gram,QUANTITY:180 ->
# USER:Dinner: 220g of  churrasco, 200g of  gołąbki, 180g of  pui la rotisor.
# ,LIST_LENGTH:3
# [1]FOOD:churrasco,UNIT:gram,QUANTITY:220
# [2]FOOD:gołąbki,UNIT:gram,QUANTITY:200
# [3]FOOD:pui la rotisor,UNIT:gram,QUANTITY:180
#
# Mismatch:
# USER:I ate 1 blini, 50g of sour cream, 20g of red caviar, and a quarter cup of dill greens.
# LIST_LENGTH:4
# [1]FOOD:blini,UNIT:piece,QUANTITY:1
# [2]FOOD:sour cream,UNIT:gram,QUANTITY:50
# [3]FOOD:red caviar,UNIT:gram,QUANTITY:20
# [4]FOOD:dill greens,UNIT:cup,QUANTITY:0 ->
# USER:I ate 1 blini, 50g of sour cream, 20g of red caviar, and a quarter cup of dill greens.
# FOOD:blini,UNIT:piece,QUANTITY:1
# FOOD:sour cream,UNIT:gram,QUANTITY:50
# FOOD:red caviar,UNIT:gram,QUANTITY:20
# FOOD:dill greens,UNIT:cup,QUANTITY:0
#
# Mismatch:
# USER:I consumed 150g of smoked salmon with 100g of rye bread and three quarters of serving of cream cheese.
# LIST_LENGTH:3
# [1]FOOD:smoked salmon,UNIT:gram,QUANTITY:150
# [2]FOOD:rye bread,UNIT:gram,QUANTITY:100
# [3]FOOD:cream cheese,UNIT:serving,QUANTITY:0 ->
# USER:I consumed 150g of smoked salmon with 100g of rye bread and three quarters of serving of cream cheese.
#
# LIST_LENGTH:3
# [1]FOOD:smoked salmon,UNIT:gram,QUANTITY:150
# [2]FOOD:rye bread,UNIT:gram,QUANTITY:100
# [3]FOOD:cream cheese,UNIT:serving,QUANTITY:0
#
# Mismatch:
# USER:I consumed 1 onigiri, 100g of pickled vegetables, and a cup of 250ml of milk.
# LIST_LENGTH:3
# [1]FOOD:onigiri,UNIT:piece,QUANTITY:1
# [2]FOOD:pickled vegetables,UNIT:gram,QUANTITY:100
# [3]FOOD:milk,UNIT:milliliter,QUANTITY:250 ->
# USER:I consumed 1 onigiri, 100g of pickled vegetables, and a cup of 250ml of milk.
# piece:1
# FOOD:onigiri
# UNIT:piece
# QUANTITY:1
# FOOD:pickled vegetables
# UNIT:gram
# QUANTITY:100
# FOOD:milk
# UNIT:milliliter
# QUANTITY:250
#
# Mismatch:
# USER:I enjoyed a bowl of 200g of curry with 100g of chicken, 50g of spinach, and 150g of basmati rice.
# LIST_LENGTH:4
# [1]FOOD:curry,UNIT:gram,QUANTITY:200
# [2]FOOD:chicken,UNIT:gram,QUANTITY:100
# [3]FOOD:spinach,UNIT:gram,QUANTITY:50
# [4]FOOD:basmati rice,UNIT:gram,QUANTITY:150 ->
# USER:I enjoyed a bowl of 200g of curry with 100g of chicken, 50g of spinach, and 150g of basmati rice.
# FOOD:curry,UNIT:gram,QUANTITY:200
# FOOD:chicken,UNIT:gram,QUANTITY:100
# FOOD:spinach,UNIT:gram,QUANTITY:50
# FOOD:basmati rice,UNIT:gram,QUANTITY:150
#
# Mismatch:
# USER:Ate 120g of com tam with 50g of grilled chicken with tablespoon of fish sauce.
# LIST_LENGTH:3
# [1]FOOD:com tam,UNIT:gram,QUANTITY:120
# [2]FOOD:grilled chicken,UNIT:gram,QUANTITY:50
# [3]FOOD:fish sauce,UNIT:tablespoon,QUANTITY:1 ->
# USER:Ate 120g of com tam with 50g of grilled chicken with tablespoon of fish sauce.
# :FOOD:com tam,UNIT:gram,QUANTITY:120
# LIST_LENGTH:3
# [1]FOOD:com tam,UNIT:gram,QUANTITY:120
# [2]FOOD:grilled chicken,UNIT:gram,QUANTITY:50
# [3]FOOD:fish sauce,UNIT:tablespoon,QUANTITY:1
#
# Mismatch:
# USER:I prepared a breakfast of 200g of udon noodles with 100g of chicken and a handful of green onions.
# LIST_LENGTH:3
# [1]FOOD:udon noodles,UNIT:gram,QUANTITY:200
# [2]FOOD:chicken,UNIT:gram,QUANTITY:100
# [3]FOOD:green onions,UNIT:handful,QUANTITY:1 ->
# USER:I prepared a breakfast of 200g of udon noodles with 100g of chicken and a handful of green onions.
# FOOD:udon noodles,UNIT:gram,QUANTITY:200
# FOOD:chicken,UNIT:gram,QUANTITY:100
# FOOD:green onions,UNIT:handful,QUANTITY:1
# LIST_LENGTH:3
# [1]FOOD:udon noodles,UNIT:gram,QUANTITY:200
# [2]FOOD:chicken,UNIT:gram,QUANTITY:100
# [3]FOOD:green onions,UNIT:handful,QUANTITY:1
#
# Mismatch:
# USER:I enjoyed 300g of banh canh with 150g of crab and a serving of chili sauce.
# LIST_LENGTH:3
# [1]FOOD:banh canh,UNIT:gram,QUANTITY:300
# [2]FOOD:crab,UNIT:gram,QUANTITY:150
# [3]FOOD:chili sauce,UNIT:serving,QUANTITY:1 ->
# USER:I enjoyed 300g of banh canh with 150g of crab and a serving of chili sauce.
# FOOD:banh canh,UNIT:gram,QUANTITY:300
# FOOD:crab,UNIT:gram,QUANTITY:150
# FOOD:chili sauce,UNIT:serving,QUANTITY:1
#
# Mismatch:
# USER:I enjoyed 250g of curry with 150g of rice and a glass of mango lassi.
# LIST_LENGTH:3
# [1]FOOD:curry,UNIT:gram,QUANTITY:250
# [2]FOOD:rice,UNIT:gram,QUANTITY:150
# [3]FOOD:mango lassi,UNIT:glass,QUANTITY:1 ->
# USER:I enjoyed 250g of curry with 150g of rice and a glass of mango lassi.
#
# LIST_LENGTH:3
# [1]FOOD:curry,UNIT:gram,QUANTITY:250
# [2]FOOD:rice,UNIT:gram,QUANTITY:150
# [3]FOOD:mango lassi,UNIT:glass,QUANTITY:1
#
# Mismatch:
# USER:I had 120g of carne al pastor with three gingerbreads with cottage cheese and one and a half plates of radishes.
# LIST_LENGTH:3
# [1]FOOD:carne al pastor,UNIT:gram,QUANTITY:120
# [2]FOOD:gingerbreads with cottage cheese,UNIT:piece,QUANTITY:3
# [3]FOOD:radishes,UNIT:plate,QUANTITY:1 ->
# USER:I had 120g of carne al pastor with three gingerbreads with cottage cheese and one and a half plates of radishes.
# :FOOD:carne al pastor,UNIT:gram,QUANTITY:120
# :FOOD:gingerbreads with cottage cheese,UNIT:piece,QUANTITY:3
# :FOOD:radishes,UNIT:plate,QUANTITY:1
# [1]FOOD:carne al pastor,UNIT:gram,QUANTITY:120
# [2]FOOD:gingerbreads with cottage cheese,UNIT:piece,QUANTITY:3
# [3]FOOD:radishes,UNIT:plate,QUANTITY:1
#
# Mismatch:
# USER:I consumed 200g of beef and vegetable pot pie with 150g of mashed turnips and a roll.
# LIST_LENGTH:3
# [1]FOOD:beef and vegetable pot pie,UNIT:gram,QUANTITY:200
# [2]FOOD:mashed turnips,UNIT:gram,QUANTITY:150
# [3]FOOD:roll,UNIT:piece,QUANTITY:1 ->
# USER:I consumed 200g of beef and vegetable pot pie with 150g of mashed turnips and a roll.
#
# LIST_LENGTH:3
# [1]FOOD:beef and vegetable pot pie,UNIT:gram,QUANTITY:200
# [2]FOOD:mashed turnips,UNIT:gram,QUANTITY:150
# [3]FOOD:roll,UNIT:piece,QUANTITY:1
#
# Mismatch:
# USER:Enjoyed 200g of xoi xeo with 50g of mung beans and a two thirds of a cup of fish sauce.
# LIST_LENGTH:3
# [1]FOOD:xoi xeo,UNIT:gram,QUANTITY:200
# [2]FOOD:mung beans,UNIT:gram,QUANTITY:50
# [3]FOOD:fish sauce,UNIT:cup,QUANTITY:0 ->
# USER:Enjoyed 200g of xoi xeo with 50g of mung beans and a two thirds of a cup of fish sauce.
# FOOD:xoi xeo,UNIT:gram,QUANTITY:200
# FOOD:mung beans,UNIT:gram,QUANTITY:50
# FOOD:fish sauce,UNIT:cup,QUANTITY:0
# LIST_LENGTH:3
# [1]FOOD:xoi xeo,UNIT:gram,QUANTITY:200
# [2]FOOD:mung beans,UNIT:gram,QUANTITY:50
# [3]FOOD:fish sauce,UNIT:cup,QUANTITY:0
#
# Mismatch:
# USER:I had 250g of sweet potato with 100g of black sesame paste and 1 orange.
# LIST_LENGTH:3
# [1]FOOD:sweet potato,UNIT:gram,QUANTITY:250
# [2]FOOD:black sesame paste,UNIT:gram,QUANTITY:100
# [3]FOOD:orange,UNIT:piece,QUANTITY:1 ->
# USER:I had 250g of sweet potato with 100g of black sesame paste and 1 orange.
# :FOOD:sweet potato,UNIT:gram,QUANTITY:250
# :FOOD:black sesame paste,UNIT:gram,QUANTITY:100
# :FOOD:orange,UNIT:piece,QUANTITY:1
#
# Mismatch:
# USER:Ate 80g of falafel, 50g of hummus, and a pita bread.
# LIST_LENGTH:3
# [1]FOOD:falafel,UNIT:gram,QUANTITY:80
# [2]FOOD:hummus,UNIT:gram,QUANTITY:50
# [3]FOOD:pita bread,UNIT:piece,QUANTITY:1 ->
# USER:Ate 80g of falafel, 50g of hummus, and a pita bread.
# FOOD:falafel,UNIT:gram,QUANTITY:80
# FOOD:hummus,UNIT:gram,QUANTITY:50
# FOOD:pita bread,UNIT:piece,QUANTITY:1
# LIST_LENGTH:3
# [1]FOOD:falafel,UNIT:gram,QUANTITY:80
# [2]FOOD:hummus,UNIT:gram,QUANTITY:50
# [3]FOOD:pita bread,UNIT:piece,QUANTITY:1
#
# Mismatch:
# USER:120g of  japchae, 80g of  mushrooms, 150g of  mixed greens salad, and a peach.
# LIST_LENGTH:4
# [1]FOOD:japchae,UNIT:gram,QUANTITY:120
# [2]FOOD:mushrooms,UNIT:gram,QUANTITY:80
# [3]FOOD:mixed greens salad,UNIT:gram,QUANTITY:150
# [4]FOOD:peach,UNIT:piece,QUANTITY:1 ->
# USER:120g of  japchae, 80g of  mushrooms, 150g of  mixed greens salad, and a peach.
# FOOD:japchae,UNIT:gram,QUANTITY:120
# FOOD:mushrooms,UNIT:gram,QUANTITY:80
# FOOD:mixed greens salad,UNIT:gram,QUANTITY:150
# [peach]FOOD:peach,UNIT:piece,QUANTITY:1
#
# Mismatch:
# USER:I ate 150g of beef rendang, 50g of potatoes, three quarters of a cup of coffee with cream, and half a bowl of rice soup.
# LIST_LENGTH:4
# [1]FOOD:beef rendang,UNIT:gram,QUANTITY:150
# [2]FOOD:potatoes,UNIT:gram,QUANTITY:50
# [3]FOOD:coffee with cream,UNIT:cup,QUANTITY:0
# [4]FOOD:rice soup,UNIT:bowl,QUANTITY:0 ->
# USER:I ate 150g of beef rendang, 50g of potatoes, three quarters of a cup of coffee with cream, and half a bowl of rice soup.
# :FOOD:beef rendang,UNIT:gram,QUANTITY:150
# :FOOD:potatoes,UNIT:gram,QUANTITY:50
# :FOOD:coffee with cream,UNIT:cup,QUANTITY:0
# :FOOD:rice soup,UNIT:bowl,QUANTITY:0
#
# Mismatch:
# USER:Had a lunch of 250g of fried rice with 200g of chicken and 50g of green peas.
# LIST_LENGTH:3
# [1]FOOD:fried rice,UNIT:gram,QUANTITY:250
# [2]FOOD:chicken,UNIT:gram,QUANTITY:200
# [3]FOOD:green peas,UNIT:gram,QUANTITY:50 ->
# USER:Had a lunch of 250g of fried rice with 200g of chicken and 50g of green peas.
# :FOOD:fried rice,UNIT:gram,QUANTITY:250
# :FOOD:chicken,UNIT:gram,QUANTITY:200
# :FOOD:green peas,UNIT:gram,QUANTITY:50
# LIST_LENGTH:3
# [1]FOOD:fried rice,UNIT:gram,QUANTITY:250
# [2]FOOD:chicken,UNIT:gram,QUANTITY:200
# [3]FOOD:green peas,UNIT:gram,QUANTITY:50
#
# Mismatch:
# USER:Lunch: 250g of creamy tomato soup with cheese, 180g of gelatinous fruit salad, 140g of garlic bread.
# LIST_LENGTH:3
# [1]FOOD:creamy tomato soup with cheese,UNIT:gram,QUANTITY:250
# [2]FOOD:gelatinous fruit salad,UNIT:gram,QUANTITY:180
# [3]FOOD:garlic bread,UNIT:gram,QUANTITY:140 ->
# USER:Lunch: 250g of creamy tomato soup with cheese, 180g of gelatinous fruit salad, 140g of garlic bread.
# :FOOD:creamy tomato soup with cheese,UNIT:gram,QUANTITY:250
# :FOOD:gelatinous fruit salad,UNIT:gram,QUANTITY:180
# :FOOD:garlic bread,UNIT:gram,QUANTITY:140
#
# Mismatch:
# USER:I had a colorful plate with 100g of beets, 150g of cooked quinoa, and 50g of goat cheese, drizzled with olive oil.
# LIST_LENGTH:3
# [1]FOOD:beets,UNIT:gram,QUANTITY:100
# [2]FOOD:cooked quinoa,UNIT:gram,QUANTITY:150
# [3]FOOD:goat cheese with olive oil,UNIT:gram,QUANTITY:50 ->
# USER:I had a colorful plate with 100g of beets, 150g of cooked quinoa, and 50g of goat cheese, drizzled with olive oil.
# :FOOD:beets,UNIT:gram,QUANTITY:100
# :FOOD:quinoa,UNIT:gram,QUANTITY:150
# :FOOD:goat cheese,UNIT:gram,QUANTITY:50
# :FOOD:olive oil,UNIT:piece,QUANTITY:1
#
# Mismatch:
# USER:Enjoyed 250g of shrimp tacos with 100g of pico de gallo and a lime wedge.
# LIST_LENGTH:3
# [1]FOOD:shrimp tacos,UNIT:gram,QUANTITY:250
# [2]FOOD:pico de gallo,UNIT:gram,QUANTITY:100
# [3]FOOD:lime wedge,UNIT:piece,QUANTITY:1 ->
# USER:Enjoyed 250g of shrimp tacos with 100g of pico de gallo and a lime wedge.
# ats:FOOD:shrimp tacos,UNIT:gram,QUANTITY:250
# LIST_LENGTH:3
# [1]FOOD:pico de gallo,UNIT:gram,QUANTITY:100
# [2]FOOD:lime wedge,UNIT:piece,QUANTITY:1
# [3]FOOD:shrimp tacos,UNIT:gram,QUANTITY:250
#
# Mismatch:
# USER:Had 200g of poutine with a side of 150g of coleslaw.
# LIST_LENGTH:2
# [1]FOOD:poutine,UNIT:gram,QUANTITY:200
# [2]FOOD:coleslaw,UNIT:gram,QUANTITY:150 ->
# USER:Had 200g of poutine with a side of 150g of coleslaw.
# FOOD:poutine,UNIT:gram,QUANTITY:200
# [2]
# LIST_LENGTH:2
# [2]FOOD:coleslaw,UNIT:gram,QUANTITY:150
# [3]FOOD:poutine,UNIT:gram,QUANTITY:200
#
# Mismatch:
# USER:I enjoyed 200g of kimchi with 1 bowl of rice and 2 fried eggs on the side.
# LIST_LENGTH:3
# [1]FOOD:kimchi,UNIT:gram,QUANTITY:200
# [2]FOOD:rice,UNIT:bowl,QUANTITY:1
# [3]FOOD:fried eggs,UNIT:piece,QUANTITY:2 ->
# USER:I enjoyed 200g of kimchi with 1 bowl of rice and 2 fried eggs on the side.
# FOOD:kimchi,UNIT:gram,QUANTITY:200
# FOOD:rice,UNIT:bowl,QUANTITY:1
# FOOD:fried eggs,UNIT:piece,QUANTITY:2
# LIST_LENGTH:3
# [1]FOOD:kimchi,UNIT:gram,QUANTITY:200
# [2]FOOD:rice,UNIT:bowl,QUANTITY:1
# [3]FOOD:fried eggs,UNIT:piece,QUANTITY:2
#
# Mismatch:
# USER:I prepared a snack with 100g of celery sticks, 50g of peanut butter, and a handful of sunflower seeds.
# LIST_LENGTH:3
# [1]FOOD:celery sticks,UNIT:gram,QUANTITY:100
# [2]FOOD:peanut butter,UNIT:gram,QUANTITY:50
# [3]FOOD:sunflower seeds,UNIT:handful,QUANTITY:1 ->
# USER:I prepared a snack with 100g of celery sticks, 50g of peanut butter, and a handful of sunflower seeds.
#  butter:peanut butter, quantity:50
#  vegetables:celery sticks, quantity:100
#  seeds:sunflower seeds, quantity:1
#
# Mismatch:
# USER:Salad: 100g of  brazilian salad, 120g of  polish cucumber salad, 80g of  romanian green bean salad.
# LIST_LENGTH:3
# [1]FOOD:brazilian salad,UNIT:gram,QUANTITY:100
# [2]FOOD:polish cucumber salad,UNIT:gram,QUANTITY:120
# [3]FOOD:romanian green bean salad,UNIT:gram,QUANTITY:80 ->
# USER:Salad: 100g of  brazilian salad, 120g of  polish cucumber salad, 80g of  romanian green bean salad.
# adDITION_LENGTH:3
# [1]FOOD:brazilian salad,UNIT:gram,QUANTITY:100
# [2]FOOD:polish cucumber salad,UNIT:gram,QUANTITY:120
# [3]FOOD:romanian green bean salad,UNIT:gram,QUANTITY:80
#
# Mismatch:
# USER:Treats: 100g Tiramisu (Italian), 150g Mochi (Japanese), 200g Brigadeiro (Brazilian), 50g Baklava (Turkish), 250ml Fresh Lemonade (American).
# LIST_LENGTH:5
# [1]FOOD:Tiramisu,UNIT:gram,QUANTITY:100
# [2]FOOD:Mochi,UNIT:gram,QUANTITY:150
# [3]FOOD:Brigadeiro,UNIT:gram,QUANTITY:200
# [4]FOOD:Baklava,UNIT:gram,QUANTITY:50
# [5]FOOD:Fresh Lemonade,UNIT:milliliter,QUANTITY:250 ->
# USER:Treats: 100g Tiramisu (Italian), 150g Mochi (Japanese), 200g Brigadeiro (Brazilian), 50g Baklava (Turkish), 250ml Fresh Lemonade (American).
# :FOOD:Tiramisu,UNIT:gram,QUANTITY:100
# :FOOD:Mochi,UNIT:gram,QUANTITY:150
# :FOOD:Brigadeiro,UNIT:gram,QUANTITY:200
# :FOOD:Baklava,UNIT:gram,QUANTITY:50
# :FOOD:Fresh Lemonade,UNIT:milliliter,QUANTITY:250
#
# Mismatch:
# USER:Enjoyed 150g of chicken tikka masala with 100g of naan bread.
# LIST_LENGTH:2
# [1]FOOD:chicken tikka masala,UNIT:gram,QUANTITY:150
# [2]FOOD:naan bread,UNIT:gram,QUANTITY:100 ->
# USER:Enjoyed 150g of chicken tikka masala with 100g of naan bread.
# ,LIST_LENGTH:2
# [1]FOOD:chicken tikka masala,UNIT:gram,QUANTITY:150
# [2]FOOD:naan bread,UNIT:gram,QUANTITY:100
#
# Mismatch:
# USER:I had a bowl of 300g of chili with 2 corn tortillas and a glass of beer.
# LIST_LENGTH:3
# [1]FOOD:chili,UNIT:gram,QUANTITY:300
# [2]FOOD:corn tortillas,UNIT:piece,QUANTITY:2
# [3]FOOD:beer,UNIT:glass,QUANTITY:1 ->
# USER:I had a bowl of 300g of chili with 2 corn tortillas and a glass of beer.
# FOOD:chili,UNIT:gram,QUANTITY:300
# LIST_LENGTH:3
# [1]FOOD:chili,UNIT:gram,QUANTITY:300
# [2]FOOD:corn tortillas,UNIT:piece,QUANTITY:2
# [3]FOOD:beer,UNIT:glass,QUANTITY:1
#
# Mismatch:
# USER:I enjoyed 300g of beef barbacoa with 2 flour tortillas and 100g of salsa.
# LIST_LENGTH:3
# [1]FOOD:beef barbacoa,UNIT:gram,QUANTITY:300
# [2]FOOD:flour tortillas,UNIT:piece,QUANTITY:2
# [3]FOOD:salsa,UNIT:gram,QUANTITY:100 ->
# USER:I enjoyed 300g of beef barbacoa with 2 flour tortillas and 100g of salsa.
# ,LIST_LENGTH:3
# [1]FOOD:beef barbacoa,UNIT:gram,QUANTITY:300
# [2]FOOD:flour tortillas,UNIT:piece,QUANTITY:2
# [3]FOOD:salsa,UNIT:gram,QUANTITY:100
#
# Mismatch:
# USER:Lunch: 200g of Shchi (Cabbage soup) with a five tablespoons of sour cream and 1 slice of rye bread.
# LIST_LENGTH:3
# [1]FOOD:Shchi,UNIT:gram,QUANTITY:200
# [2]FOOD:sour cream,UNIT:tablespoon,QUANTITY:5
# [3]FOOD:rye bread,UNIT:slice,QUANTITY:1 ->
# USER:Lunch: 200g of Shchi (Cabbage soup) with a five tablespoons of sour cream and 1 slice of rye bread.
# :FOOD:Shchi,UNIT:gram,QUANTITY:200
# :FOOD:sour cream,UNIT:tablespoon,QUANTITY:5
# :FOOD:rye bread,UNIT:slice,QUANTITY:1
#
# Mismatch:
# USER:Ate 150g of grilled lamb chops with 200g of roasted potatoes and a teaspoon of rosemary.
# LIST_LENGTH:3
# [1]FOOD:grilled lamb chops,UNIT:gram,QUANTITY:150
# [2]FOOD:roasted potatoes,UNIT:gram,QUANTITY:200
# [3]FOOD:rosemary,UNIT:teaspoon,QUANTITY:1 ->
# USER:Ate 150g of grilled lamb chops with 200g of roasted potatoes and a teaspoon of rosemary.
# :FOOD:grilled lamb chops,UNIT:gram,QUANTITY:150
# :FOOD:roasted potatoes,UNIT:gram,QUANTITY:200
# :FOOD:rosemary,UNIT:teaspoon,QUANTITY:1
#
# Mismatch:
# USER:I had 200g of sushi rolls with 50g of wasabi and a cup of 200ml miso soup.
# LIST_LENGTH:3
# [1]FOOD:sushi rolls,UNIT:gram,QUANTITY:200
# [2]FOOD:wasabi,UNIT:gram,QUANTITY:50
# [3]FOOD:miso soup,UNIT:milliliter,QUANTITY:200 ->
# USER:I had 200g of sushi rolls with 50g of wasabi and a cup of 200ml miso soup.
# FOOD:sushi rolls,UNIT:gram,QUANTITY:200
# FOOD:wasabi,UNIT:gram,QUANTITY:50
# FOOD:miso soup,UNIT:milliliter,QUANTITY:200
# LIST_LENGTH:3
# [1]FOOD:sushi rolls,UNIT:gram,QUANTITY:200
# [2]FOOD:wasabi,UNIT:gram,QUANTITY:50
# [3]FOOD:miso soup,UNIT:milliliter,QUANTITY:200
#
# Mismatch:
# USER:Enjoyed a dessert of 2 bowls of vanilla ice cream with 50g of chocolate syrup.
# LIST_LENGTH:2
# [1]FOOD:vanilla ice cream,UNIT:bowl,QUANTITY:2
# [2]FOOD:chocolate syrup,UNIT:gram,QUANTITY:50 ->
# USER:Enjoyed a dessert of 2 bowls of vanilla ice cream with 50g of chocolate syrup.
# FOOD:vanilla ice cream,UNIT:bowls,QUANTITY:2
# LIST_LENGTH:2
# [1]FOOD:vanilla ice cream,UNIT:bowls,QUANTITY:2
# [2]FOOD:chocolate syrup,UNIT:gram,QUANTITY:50
#
# Mismatch:
# USER:Treats: 130g of brownies, 90g of pudding, 80g of candy.
# LIST_LENGTH:3
# [1]FOOD:brownies,UNIT:gram,QUANTITY:130
# [2]FOOD:pudding,UNIT:gram,QUANTITY:90
# [3]FOOD:candy,UNIT:gram,QUANTITY:80 ->
# USER:Treats: 130g of brownies, 90g of pudding, 80g of candy.
# :FOOD:brownies,UNIT:gram,QUANTITY:130
# :FOOD:pudding,UNIT:gram,QUANTITY:90
# :FOOD:candy,UNIT:gram,QUANTITY:80
# ...
# [2]FOOD:shredded cheese,UNIT:gram,QUANTITY:100
# [3]FOOD:cornbread,UNIT:slice,QUANTITY:1 ->
# USER:Had a bowl of 250g of beef chili with 100g of shredded cheese and a slice of cornbread.
# FOOD:beef chili,UNIT:gram,QUANTITY:250
# LIST_LENGTH:3
# [1]FOOD:beef chili,UNIT:gram,QUANTITY:250
# [2]FOOD:shredded cheese,UNIT:gram,QUANTITY:100
# [3]FOOD:cornbread,UNIT:slice,QUANTITY:1
#
# Mismatch:
# USER:Dinner: 300g of kebab with rice, 200g of Shirazi salad, 150g of tzatziki.
# LIST_LENGTH:3
# [1]FOOD:kebab with rice,UNIT:gram,QUANTITY:300
# [2]FOOD:Shirazi salad,UNIT:gram,QUANTITY:200
# [3]FOOD:tzatziki,UNIT:gram,QUANTITY:150 ->
# USER:Dinner: 300g of kebab with rice, 200g of Shirazi salad, 150g of tzatziki.
# :FOOD:kebab with rice,UNIT:gram,QUANTITY:300
# :FOOD:Shirazi salad,UNIT:gram,QUANTITY:200
# :FOOD:tzatziki,UNIT:gram,QUANTITY:150
# [1]FOOD:kebab with rice,UNIT:gram,QUANTITY:300
# [2]FOOD:Shirazi salad,UNIT:gram,QUANTITY:200
# [3]FOOD:tzatziki,UNIT:gram,QUANTITY:150
#
# Mismatch:
# USER:Snack: 100g of  Graham balls, 70g of  ube ice cream, 50g of  pringles.
# LIST_LENGTH:3
# [1]FOOD:Graham balls,UNIT:gram,QUANTITY:100
# [2]FOOD:ube ice cream,UNIT:gram,QUANTITY:70
# [3]FOOD:pringles,UNIT:gram,QUANTITY:50 ->
# USER:Snack: 100g of  Graham balls, 70g of  ube ice cream, 50g of  pringles.
# 1_LENGTH:gram,1_QUANTITY:100
# 2_LENGTH:gram,1_QUANTITY:70
# 3_LENGTH:gram,1_QUANTITY:50
# [FOOD:Graham balls,UNIT:gram,QUANTITY:100
# FOOD:ube ice cream,UNIT:gram,QUANTITY:70
# FOOD:pringles,UNIT:gram,QUANTITY:50
#
# Mismatch:
# USER:I ate 100g of chocolate cake, 50g of chocolate frosting, 3 chocolate chips, and a glass of milk.
# LIST_LENGTH:4
# [1]FOOD:chocolate cake,UNIT:gram,QUANTITY:100
# [2]FOOD:chocolate frosting,UNIT:gram,QUANTITY:50
# [3]FOOD:chocolate chips,UNIT:piece,QUANTITY:3
# [4]FOOD:milk,UNIT:glass,QUANTITY:1 ->
# USER:I ate 100g of chocolate cake, 50g of chocolate frosting, 3 chocolate chips, and a glass of milk.
# FOOD:chocolate cake,UNIT:gram,QUANTITY:100
# FOOD:chocolate frosting,UNIT:gram,QUANTITY:50
# FOOD:chocolate chips,UNIT:piece,QUANTITY:3
# FOOD:milk,UNIT:glass,QUANTITY:1
#
# Mismatch:
# USER:I ate 100g of sushi, 50g of wasabi, 2 pickled ginger slices, and a soy sauce cup.
# LIST_LENGTH:4
# [1]FOOD:sushi,UNIT:gram,QUANTITY:100
# [2]FOOD:wasabi,UNIT:gram,QUANTITY:50
# [3]FOOD:pickled ginger,UNIT:slice,QUANTITY:2
# [4]FOOD:soy sauce,UNIT:cup,QUANTITY:1 ->
# USER:I ate 100g of sushi, 50g of wasabi, 2 pickled ginger slices, and a soy sauce cup.
# FOOD:sushi,UNIT:gram,QUANTITY:100
# FOOD:wasabi,UNIT:gram,QUANTITY:50
# FOOD:pickled ginger,UNIT:slice,QUANTITY:2
# FOOD:soy sauce,UNIT:cup,QUANTITY:1
#
# Mismatch:
# USER:Breakfast: 170g of Persian omelette, 120g of fresh herbs, 100g of flatbread.
# LIST_LENGTH:3
# [1]FOOD:Persian omelette,UNIT:gram,QUANTITY:170
# [2]FOOD:fresh herbs,UNIT:gram,QUANTITY:120
# [3]FOOD:flatbread,UNIT:gram,QUANTITY:100 ->
# USER:Breakfast: 170g of Persian omelette, 120g of fresh herbs, 100g of flatbread.
# FOOD:Persian omelette,UNIT:gram,QUANTITY:170
# FOOD:fresh herbs,UNIT:gram,QUANTITY:120
# FOOD:flatbread,UNIT:gram,QUANTITY:100
# LIST_LENGTH:3
# [1]FOOD:Persian omelette,UNIT:gram,QUANTITY:170
# [2]FOOD:fresh herbs,UNIT:gram,QUANTITY:120
# [3]FOOD:flatbread,UNIT:gram,QUANTITY:100
#
# Mismatch:
# USER:120g of  Bibimbap, 80g of  greens, 150g of  brown rice, and 100ml of  tea.
# LIST_LENGTH:4
# [1]FOOD:Bibimbap,UNIT:gram,QUANTITY:120
# [2]FOOD:greens,UNIT:gram,QUANTITY:80
# [3]FOOD:brown rice,UNIT:gram,QUANTITY:150
# [4]FOOD:tea,UNIT:milliliter,QUANTITY:100 ->
# USER:120g of  Bibimbap, 80g of  greens, 150g of  brown rice, and 100ml of  tea.
# FOOD:Bibimbap,UNIT:gram,QUANTITY:120
# FOOD:greens,UNIT:gram,QUANTITY:80
# FOOD:brown rice,UNIT:gram,QUANTITY:150
# FOOD:tea,UNIT:milliliter,QUANTITY:100
#
# Mismatch:
# USER:Lunch: 240g of falafel wrap, 150g of tahini sauce, 130g of coleslaw.
# LIST_LENGTH:3
# [1]FOOD:falafel wrap,UNIT:gram,QUANTITY:240
# [2]FOOD:tahini sauce,UNIT:gram,QUANTITY:150
# [3]FOOD:coleslaw,UNIT:gram,QUANTITY:130 ->
# USER:Lunch: 240g of falafel wrap, 150g of tahini sauce, 130g of coleslaw.
# :focal_length:3
# [1]FOOD:falafel wrap,UNIT:gram,QUANTITY:240
# [2]FOOD:tahini sauce,UNIT:gram,QUANTITY:150
# [3]FOOD:coleslaw,UNIT:gram,QUANTITY:130
#
# Mismatch:
# USER:Snack: 100g of dried apricots, 50g of walnuts, and a glass of kefir.
# LIST_LENGTH:3
# [1]FOOD:dried apricots,UNIT:gram,QUANTITY:100
# [2]FOOD:walnuts,UNIT:gram,QUANTITY:50
# [3]FOOD:kefir,UNIT:glass,QUANTITY:1 ->
# USER:Snack: 100g of dried apricots, 50g of walnuts, and a glass of kefir.
# :FOOD:dried apricots,UNIT:gram,QUANTITY:100
# :FOOD:walnuts,UNIT:gram,QUANTITY:50
# :FOOD:kefir,UNIT:glass,QUANTITY:1
# LIST_LENGTH:3
# [1]FOOD:dried apricots,UNIT:gram,QUANTITY:100
# [2]FOOD:walnuts,UNIT:gram,QUANTITY:50
# [3]FOOD:kefir,UNIT:glass,QUANTITY:1
#
# Mismatch:
# USER:I ate 1 slice of French toast with 100g of blueberries and 1 teaspoon of cinnamon.
# LIST_LENGTH:3
# [1]FOOD:French toast,UNIT:slice,QUANTITY:1
# [2]FOOD:blueberries,UNIT:gram,QUANTITY:100
# [3]FOOD:cinnamon,UNIT:teaspoon,QUANTITY:1 ->
# USER:I ate 1 slice of French toast with 100g of blueberries and 1 teaspoon of cinnamon.
# :FOOD:French toast,UNIT:slice,QUANTITY:1
# :FOOD:blueberries,UNIT:gram,QUANTITY:100
# :FOOD:cinnamon,UNIT:teaspoon,QUANTITY:1
#
# Mismatch:
# USER:Ate 1 baguette, 100g of brie cheese, a cup of cappuccino, and a side of olives.
# LIST_LENGTH:4
# [1]FOOD:baguette,UNIT:piece,QUANTITY:1
# [2]FOOD:brie cheese,UNIT:gram,QUANTITY:100
# [3]FOOD:cappuccino,UNIT:cup,QUANTITY:1
# [4]FOOD:olives,UNIT:side,QUANTITY:1 ->
# USER:Ate 1 baguette, 100g of brie cheese, a cup of cappuccino, and a side of olives.
# :FOOD:baguette,UNIT:piece,QUANTITY:1
# :FOOD:brie cheese,UNIT:gram,QUANTITY:100
# :FOOD:cappuccino,UNIT:cup,QUANTITY:1
# :FOOD:olives,UNIT:side,QUANTITY:1
#
# Mismatch:
# USER:I had 150g of freekeh with 200g of lamb kofta and a side of 100g of tabbouleh.
# LIST_LENGTH:3
# [1]FOOD:freekeh,UNIT:gram,QUANTITY:150
# [2]FOOD:lamb kofta,UNIT:gram,QUANTITY:200
# [3]FOOD:tabbouleh,UNIT:gram,QUANTITY:100 ->
# USER:I had 150g of freekeh with 200g of lamb kofta and a side of 100g of tabbouleh.
# FOOD:freekeh,UNIT:gram,QUANTITY:150
# FOOD:lamb kofta,UNIT:gram,QUANTITY:200
# FOOD:tabbouleh,UNIT:gram,QUANTITY:100
# [1]FOOD:freekeh,UNIT:gram,QUANTITY:150
# [2]FOOD:lamb kofta,UNIT:gram,QUANTITY:200
# [3]FOOD:tabbouleh,UNIT:gram,QUANTITY:100
#
# Mismatch:
# USER:I had 250g of cauliflower rice with 120g of shrimp and 50g of coconut oil.
# LIST_LENGTH:3
# [1]FOOD:cauliflower rice,UNIT:gram,QUANTITY:250
# [2]FOOD:shrimp,UNIT:gram,QUANTITY:120
# [3]FOOD:coconut oil,UNIT:gram,QUANTITY:50 ->
# USER:I had 250g of cauliflower rice with 120g of shrimp and 50g of coconut oil.
# FOOD:cauliflower rice,UNIT:gram,QUANTITY:250
# FOOD:shrimp,UNIT:gram,QUANTITY:120
# FOOD:coconut oil,UNIT:gram,QUANTITY:50
# LIST_LENGTH:3
# [1]FOOD:cauliflower rice,UNIT:gram,QUANTITY:250
# [2]FOOD:shrimp,UNIT:gram,QUANTITY:120
# [3]FOOD:coconut oil,UNIT:gram,QUANTITY:50
#
# Mismatch:
# USER:Lunch: 150g of  ukrainian borscht with a toast with butter and a third of a glass of cognac.
# LIST_LENGTH:3
# [1]FOOD:ukrainian borscht,UNIT:gram,QUANTITY:150
# [2]FOOD:toast with butter,UNIT:piece,QUANTITY:1
# [3]FOOD:cognac,UNIT:glass,QUANTITY:0 ->
# USER:Lunch: 150g of  ukrainian borscht with a toast with butter and a third of a glass of cognac.
# FOOD:ukrainian borscht,UNIT:gram,QUANTITY:150
# FOOD:toast with butter,UNIT:piece,QUANTITY:1
# FOOD:cognac,UNIT:glass,QUANTITY:0
#
# Mismatch:
# USER:Had 300g of karelian stew with a side of 150g of rye porridge.
# LIST_LENGTH:2
# [1]FOOD:karelian stew,UNIT:gram,QUANTITY:300
# [2]FOOD:rye porridge,UNIT:gram,QUANTITY:150 ->
# USER:Had 300g of karelian stew with a side of 150g of rye porridge.
# :FOOD:karelian stew,UNIT:gram,QUANTITY:300
# :FOOD:rye porridge,UNIT:gram,QUANTITY:150
# [1]FOOD:karelian stew,UNIT:gram,QUANTITY:300
# [2]FOOD:rye porridge,UNIT:gram,QUANTITY:150
#
# Mismatch:
# USER:Had 150g of stuffed cabbage rolls with a side of 200g of mashed carrots.
# LIST_LENGTH:2
# [1]FOOD:stuffed cabbage rolls,UNIT:gram,QUANTITY:150
# [2]FOOD:mashed carrots,UNIT:gram,QUANTITY:200 ->
# USER:Had 150g of stuffed cabbage rolls with a side of 200g of mashed carrots.
# FOOD:stuffed cabbage rolls,UNIT:gram,QUANTITY:150
# LIST_LENGTH:2
# [1]FOOD:stuffed cabbage rolls,UNIT:gram,QUANTITY:150
# [2]FOOD:mashed carrots,UNIT:gram,QUANTITY:200
#
# Mismatch:
# USER:a quarter cup of aquavit with 1 slice of cured salmon and half a serving of rye chips.
# LIST_LENGTH:3
# [1]FOOD:akvavit,UNIT:cup,QUANTITY:0
# [2]FOOD:cured salmon,UNIT:slice,QUANTITY:1
# [3]FOOD:rye chips,UNIT:serving,QUANTITY:0 ->
# USER:a quarter cup of aquavit with 1 slice of cured salmon and half a serving of rye chips.
#
# LIST_LENGTH:3
# [1]FOOD:aquavit,UNIT:cup,QUANTITY:0
# [2]FOOD:cured salmon,UNIT:slice,QUANTITY:1
# [3]FOOD:rye chips,UNIT:serving,QUANTITY:0
#
# Mismatch:
# USER:For dinner, I had 200g of duck breast with 100g of spinach and a teaspoon of sesame oil.
# LIST_LENGTH:3
# [1]FOOD:duck breast,UNIT:gram,QUANTITY:200
# [2]FOOD:spinach,UNIT:gram,QUANTITY:100
# [3]FOOD:sesame oil,UNIT:teaspoon,QUANTITY:1 ->
# USER:For dinner, I had 200g of duck breast with 100g of spinach and a teaspoon of sesame oil.
# DIRECTIONS:1.FOOD:duck breast,UNIT:gram,QUANTITY:200
# 2.FOOD:spinach,UNIT:gram,QUANTITY:100
# 3.FOOD:sesame oil,UNIT:teaspoon,QUANTITY:1
#
# Mismatch:
# USER:Ate 250g of fufu with 150g of egusi soup and a side of 100g of fried fish.
# LIST_LENGTH:3
# [1]FOOD:fufu,UNIT:gram,QUANTITY:250
# [2]FOOD:egusi soup,UNIT:gram,QUANTITY:150
# [3]FOOD:fried fish,UNIT:gram,QUANTITY:100 ->
# USER:Ate 250g of fufu with 150g of egusi soup and a side of 100g of fried fish.
# :FOOD:fufu,UNIT:gram,QUANTITY:250
# :FOOD:egusi soup,UNIT:gram,QUANTITY:150
# :FOOD:fried fish,UNIT:gram,QUANTITY:100
# [1]FOOD:fufu,UNIT:gram,QUANTITY:250
# [2]FOOD:egusi soup,UNIT:gram,QUANTITY:150
# [3]FOOD:fried fish,UNIT:gram,QUANTITY:100
#
# Mismatch:
# USER:I ate 2 tacos with 100g of ground beef, 50g of shredded cheese and a teaspoon of salsa.
# LIST_LENGTH:4
# [1]FOOD:tacos,UNIT:piece,QUANTITY:2
# [2]FOOD:ground beef,UNIT:gram,QUANTITY:100
# [3]FOOD:shredded cheese,UNIT:gram,QUANTITY:50
# [4]FOOD:salsa,UNIT:teaspoon,QUANTITY:1 ->
# USER:I ate 2 tacos with 100g of ground beef, 50g of shredded cheese and a teaspoon of salsa.
# :FOOD:tacos,UNIT:piece,QUANTITY:2
# :FOOD:ground beef,UNIT:gram,QUANTITY:100
# :FOOD:shredded cheese,UNIT:gram,QUANTITY:50
# :FOOD:salsa,UNIT:teaspoon,QUANTITY:1
#
# Mismatch:
# USER:For a comforting dinner, I had a plate of pork chops with creamy mushroom gravy and a couple of apricot spritz cookies for dessert.
# LIST_LENGTH:2
# [1]FOOD:pork chops with creamy mushroom gravy,UNIT:plate,QUANTITY:1
# [2]FOOD:apricot spritz cookies,UNIT:piece,QUANTITY:2 ->
# USER:For a comforting dinner, I had a plate of pork chops with creamy mushroom gravy and a couple of apricot spritz cookies for dessert.
# :FOOD:pork chops with creamy mushroom gravy,UNIT:plate,QUANTITY:1
# :FOOD:apricot spritz cookies,UNIT:piece,QUANTITY:2
# LIST_LENGTH:2
# [1]FOOD:pork chops with creamy mushroom gravy,UNIT:plate,QUANTITY:1
# [2]FOOD:apricot spritz cookies,UNIT:piece,QUANTITY:2
#
# Mismatch:
# USER:two bowls of Kasha with milk and three doughnuts with two glasses of cocktails.
# LIST_LENGTH:3
# [1]FOOD:Kasha with milk,UNIT:gram,QUANTITY:150
# [2]FOOD:doughnuts,UNIT:piece,QUANTITY:3
# [3]FOOD:cocktails,UNIT:glass,QUANTITY:2 ->
# USER:two bowls of Kasha with milk and three doughnuts with two glasses of cocktails.
# _LENGTH:2
# [1]FOOD:Kasha with milk,UNIT:piece,QUANTITY:2
# [2]FOOD:doughnuts with two glasses of cocktails,UNIT:piece,QUANTITY:3
#
# Mismatch:
# USER:For a light dinner, I had a piece of peach cobbler and a bowl of kale and almond salad with lemon and parmesan.
# LIST_LENGTH:2
# [1]FOOD:peach cobbler,UNIT:piece,QUANTITY:1
# [2]FOOD:kale and almond salad with lemon and parmesan,UNIT:bowl,QUANTITY:1 ->
# USER:For a light dinner, I had a piece of peach cobbler and a bowl of kale and almond salad with lemon and parmesan.
#  theFOOD:peach cobbler,UNIT:piece,QUANTITY:1
# LIST_LENGTH:2
# [1]FOOD:peach cobbler,UNIT:piece,QUANTITY:1
# [2]FOOD:kale and almond salad with lemon and parmesan,UNIT:bowl,QUANTITY:1
#
# Mismatch:
# USER:For lunch, I enjoyed 150g of fried rice with 100g of shrimp and 50g of peas.
# LIST_LENGTH:3
# [1]FOOD:fried rice,UNIT:gram,QUANTITY:150
# [2]FOOD:shrimp,UNIT:gram,QUANTITY:100
# [3]FOOD:peas,UNIT:gram,QUANTITY:50 ->
# USER:For lunch, I enjoyed 150g of fried rice with 100g of shrimp and 50g of peas.
# ,LIST_LENGTH:3
# [1]FOOD:fried rice,UNIT:gram,QUANTITY:150
# [2]FOOD:shrimp,UNIT:gram,QUANTITY:100
# [3]FOOD:peas,UNIT:gram,QUANTITY:50
#
# Mismatch:
# USER:100g of  Korean pancakes, 150g of  stir-fried vegetables, 200g of  white rice, and a kiwi.
# LIST_LENGTH:4
# [1]FOOD:Korean pancakes,UNIT:gram,QUANTITY:100
# [2]FOOD:stir-fried vegetables,UNIT:gram,QUANTITY:150
# [3]FOOD:white rice,UNIT:gram,QUANTITY:200
# [4]FOOD:kiwi,UNIT:piece,QUANTITY:1 ->
# USER:100g of  Korean pancakes, 150g of  stir-fried vegetables, 200g of  white rice, and a kiwi.
# FOOD:Korean pancakes,UNIT:gram,QUANTITY:100
# FOOD:stir-fried vegetables,UNIT:gram,QUANTITY:150
# FOOD:white rice,UNIT:gram,QUANTITY:200
# FOOD:kiwi,UNIT:piece,QUANTITY:1
#
# Mismatch:
# USER:Ate 1 slice of quiche, 100g of mixed greens salad, a slice of whole grain bread, and a cup of herbal tea.
# LIST_LENGTH:4
# [1]FOOD:quiche,UNIT:slice,QUANTITY:1
# [2]FOOD:mixed greens salad,UNIT:gram,QUANTITY:100
# [3]FOOD:whole grain bread,UNIT:slice,QUANTITY:1
# [4]FOOD:herbal tea,UNIT:cup,QUANTITY:1 ->
# USER:Ate 1 slice of quiche, 100g of mixed greens salad, a slice of whole grain bread, and a cup of herbal tea.
# :FOOD:quiche,UNIT:slice,QUANTITY:1
# :FOOD:mixed greens salad,UNIT:gram,QUANTITY:100
# :FOOD:whole grain bread,UNIT:slice,QUANTITY:1
# :FOOD:herbal tea,UNIT:cup,QUANTITY:1
#
# Mismatch:
# USER:I had 150g of  fruit crumble, 75g of vanilla ice cream, two cupcakes with cottage cheese, and a two tablespoons of whipped cream.
# LIST_LENGTH:4
# [1]FOOD:fruit crumble,UNIT:gram,QUANTITY:150
# [2]FOOD:vanilla ice cream,UNIT:gram,QUANTITY:75
# [3]FOOD:cupcakes with cottage cheese,UNIT:piece,QUANTITY:2
# [4]FOOD:whipped cream,UNIT:tablespoon,QUANTITY:2 ->
# USER:I had 150g of  fruit crumble, 75g of vanilla ice cream, two cupcakes with cottage cheese, and a two tablespoons of whipped cream.
# :FOOD:fruit crumble,UNIT:gram,QUANTITY:150
# :FOOD:vanilla ice cream,UNIT:gram,QUANTITY:75
# :FOOD:cottage cheese cupcakes,UNIT:piece,QUANTITY:2
# :FOOD:whipped cream,UNIT:tablespoon,QUANTITY:2
#
# Mismatch:
# USER:Treats: 140g of halva, 130g of almond baklava, 100g of rosewater pudding.
# LIST_LENGTH:3
# [1]FOOD:halva,UNIT:gram,QUANTITY:140
# [2]FOOD:almond baklava,UNIT:gram,QUANTITY:130
# [3]FOOD:rosewater pudding,UNIT:gram,QUANTITY:100 ->
# USER:Treats: 140g of halva, 130g of almond baklava, 100g of rosewater pudding.
# :LIST_LENGTH:3
# [1]FOOD:halva,UNIT:gram,QUANTITY:140
# [2]FOOD:almond baklava,UNIT:gram,QUANTITY:130
# [3]FOOD:rosewater pudding,UNIT:gram,QUANTITY:100
#
# Mismatch:
# USER:Lunch: 220g of tuna salad sandwich, 100g of potato chips, one and a half glass monster zero sugar.
# LIST_LENGTH:3
# [1]FOOD:tuna salad sandwich,UNIT:gram,QUANTITY:220
# [2]FOOD:potato chips,UNIT:gram,QUANTITY:100
# [3]FOOD:monster zero sugar,UNIT:glass,QUANTITY:1 ->
# USER:Lunch: 220g of tuna salad sandwich, 100g of potato chips, one and a half glass monster zero sugar.
# :FOOD:tuna salad sandwich,UNIT:gram,QUANTITY:220
# :FOOD:potato chips,UNIT:gram,QUANTITY:100
# :FOOD:monster zero sugar,UNIT:glass,QUANTITY:1
# [1]FOOD:tuna salad sandwich,UNIT:gram,QUANTITY:220
# [2]FOOD:potato chips,UNIT:gram,QUANTITY:100
# [3]FOOD:monster zero sugar,UNIT:glass,QUANTITY:1
#
# Mismatch:
# USER:Snack: 75g of trail mix, an apple, 100g of yogurt.
# LIST_LENGTH:3
# [1]FOOD:trail mix,UNIT:gram,QUANTITY:75
# [2]FOOD:apple,UNIT:,QUANTITY:1
# [3]FOOD:yogurt,UNIT:gram,QUANTITY:100 ->
# USER:Snack: 75g of trail mix, an apple, 100g of yogurt.
# :LIST_LENGTH:3
# [1]FOOD:trail mix,UNIT:gram,QUANTITY:75
# [2]FOOD:apple,UNIT:piece,QUANTITY:1
# [3]FOOD:yogurt,UNIT:gram,QUANTITY:100
#
# Mismatch:
# USER:Ate 2 servings of buko pandan salad with a cup of ice cream.
# LIST_LENGTH:2
# [1]FOOD:buko pandan salad,UNIT:serving,QUANTITY:2
# [2]FOOD:ice cream,UNIT:cup,QUANTITY:1 ->
# USER:Ate 2 servings of buko pandan salad with a cup of ice cream.
# :FOOD:buko pandan salad,UNIT:serving,QUANTITY:2
# :FOOD:ice cream,UNIT:cup,QUANTITY:1
# [1]FOOD:buko pandan salad,UNIT:serving,QUANTITY:2
# [2]FOOD:ice cream,UNIT:cup,QUANTITY:1
