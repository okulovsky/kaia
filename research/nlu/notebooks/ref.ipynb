# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "7"

# %%
from datasets import load_dataset

dataset = load_dataset(
    "json", data_files={"train": "datalines/train_example.jsonl"}
)

# %%
from transformers import AutoTokenizer

model_name = "google/gemma-3-270m-it"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
def format_prompt(sample):
    input = sample["INPUT"]
    output = sample["OUTPUT"]
    return f"{input}{output}" + tokenizer.eos_token

def tokenize(sample, max_length):
    prompt = f"{sample['INPUT']}"
    prompt_len = len(tokenizer(prompt)["input_ids"])
    tokenized = tokenizer(sample["text"], padding="max_length", max_length=max_length)
    pad_len = tokenized["input_ids"].count(tokenizer.pad_token_id)
    tokenized["labels"] = tokenized["input_ids"].copy()
    tokenized["labels"][: pad_len + prompt_len] = [-100] * (pad_len + prompt_len)
    return tokenized

# %%
dataset["train"][0]
# Out:
# {'INPUT': 'USER:set a timer for 3 hours\n',
#  'OUTPUT': 'HOURS:3\nMINUTES:0\nSECONDS:0'}

# %%
dataset["train"] = dataset["train"].map(lambda x: {"text": format_prompt(x)})

# %%
print(dataset["train"][0]["text"])
# Out:
# USER:set a timer for 3 hours
# HOURS:3
# MINUTES:0
# SECONDS:0<eos>

# %%
max_length = max(len(tokenizer(sample["text"])["input_ids"]) for sample in dataset["train"])

# %%
from functools import partial

dataset["train"] = dataset["train"].map(partial(tokenize, max_length=max_length), batched=False)

# %%
from transformers import (
    AutoModelForCausalLM,
    TrainingArguments,
)
from peft import LoraConfig
from trl import SFTTrainer


model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    use_cache=False,
    attn_implementation="eager",
)

# %%
peft_config = LoraConfig(
    r=16,
    lora_alpha=32,
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
    lora_dropout=0.0,
    bias="none",
    task_type="CAUSAL_LM",
)

# %%
training_args = TrainingArguments(
    output_dir="./gemma-timer-lora",
    num_train_epochs=1,
    per_device_train_batch_size=32,
    gradient_accumulation_steps=1,
    learning_rate=2e-4,
    logging_steps=10,
    save_strategy="steps",
    save_steps=0.02,
    save_total_limit=None,
    report_to="none",
    weight_decay=0.01,
    lr_scheduler_type="cosine",
    warmup_ratio=0.1,
    seed=252,
    fp16=True,
)

trainer = SFTTrainer(
    model=model,
    train_dataset=dataset["train"],
    peft_config=peft_config,
    args=training_args,
)

trainer.train()
# Out:
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': 2, 'pad_token_id': 0}.
#     <div>
#
#       <progress value='99' max='99' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [99/99 01:10, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.231100</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.186800</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.032300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.012600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.011200</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.006200</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.004900</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.008300</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.004400</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=99, training_loss=0.2525280250819645, metrics={'train_runtime': 71.7577, 'train_samples_per_second': 43.828, 'train_steps_per_second': 1.38, 'total_flos': 82521648760320.0, 'train_loss': 0.2525280250819645, 'entropy': 0.645798020892673, 'num_tokens': 132090.0, 'mean_token_accuracy': 0.9987068772315979, 'epoch': 1.0})

# %%
# !uv run convert_lora_to_gguf.py ./gemma-timer-lora/checkpoint-30 --outfile ./gguf_checkpoints/timer_checkpoint-30f16.gguf --outtype "f16"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# INFO:lora-to-gguf:Loading base model from Hugging Face: google/gemma-3-270m-it
# INFO:hf-to-gguf:gguf: indexing model part 'model.safetensors'
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:lora-to-gguf:Exporting model...
# INFO:hf-to-gguf:blk.0.ffn_down.weight.lora_a,      torch.float32 --> F16, shape = {2048, 16}
# INFO:hf-to-gguf:blk.0.ffn_down.weight.lora_b,      torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight.lora_a,      torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight.lora_b,      torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.0.ffn_up.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.0.ffn_up.weight.lora_b,        torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.0.attn_k.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.0.attn_k.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.0.attn_output.weight.lora_a,   torch.float32 --> F16, shape = {1024, 16}
# INFO:hf-to-gguf:blk.0.attn_output.weight.lora_b,   torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.0.attn_q.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.0.attn_q.weight.lora_b,        torch.float32 --> F16, shape = {16, 1024}
# INFO:hf-to-gguf:blk.0.attn_v.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.0.attn_v.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.1.ffn_down.weight.lora_a,      torch.float32 --> F16, shape = {2048, 16}
# INFO:hf-to-gguf:blk.1.ffn_down.weight.lora_b,      torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.1.ffn_gate.weight.lora_a,      torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.1.ffn_gate.weight.lora_b,      torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.1.ffn_up.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.1.ffn_up.weight.lora_b,        torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.1.attn_k.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.1.attn_k.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.1.attn_output.weight.lora_a,   torch.float32 --> F16, shape = {1024, 16}
# INFO:hf-to-gguf:blk.1.attn_output.weight.lora_b,   torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.1.attn_q.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.1.attn_q.weight.lora_b,        torch.float32 --> F16, shape = {16, 1024}
# INFO:hf-to-gguf:blk.1.attn_v.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.1.attn_v.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.10.ffn_down.weight.lora_a,     torch.float32 --> F16, shape = {2048, 16}
# INFO:hf-to-gguf:blk.10.ffn_down.weight.lora_b,     torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.10.ffn_gate.weight.lora_a,     torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.10.ffn_gate.weight.lora_b,     torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.10.ffn_up.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.10.ffn_up.weight.lora_b,       torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.10.attn_k.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.10.attn_k.weight.lora_b,       torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.10.attn_output.weight.lora_a,  torch.float32 --> F16, shape = {1024, 16}
# INFO:hf-to-gguf:blk.10.attn_output.weight.lora_b,  torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.10.attn_q.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.10.attn_q.weight.lora_b,       torch.float32 --> F16, shape = {16, 1024}
# INFO:hf-to-gguf:blk.10.attn_v.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.10.attn_v.weight.lora_b,       torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.11.ffn_down.weight.lora_a,     torch.float32 --> F16, shape = {2048, 16}
# INFO:hf-to-gguf:blk.11.ffn_down.weight.lora_b,     torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.11.ffn_gate.weight.lora_a,     torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.11.ffn_gate.weight.lora_b,     torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.11.ffn_up.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.11.ffn_up.weight.lora_b,       torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.11.attn_k.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.11.attn_k.weight.lora_b,       torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.11.attn_output.weight.lora_a,  torch.float32 --> F16, shape = {1024, 16}
# INFO:hf-to-gguf:blk.11.attn_output.weight.lora_b,  torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.11.attn_q.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.11.attn_q.weight.lora_b,       torch.float32 --> F16, shape = {16, 1024}
# INFO:hf-to-gguf:blk.11.attn_v.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.11.attn_v.weight.lora_b,       torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.12.ffn_down.weight.lora_a,     torch.float32 --> F16, shape = {2048, 16}
# INFO:hf-to-gguf:blk.12.ffn_down.weight.lora_b,     torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.12.ffn_gate.weight.lora_a,     torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.12.ffn_gate.weight.lora_b,     torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.12.ffn_up.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.12.ffn_up.weight.lora_b,       torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.12.attn_k.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.12.attn_k.weight.lora_b,       torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.12.attn_output.weight.lora_a,  torch.float32 --> F16, shape = {1024, 16}
# INFO:hf-to-gguf:blk.12.attn_output.weight.lora_b,  torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.12.attn_q.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.12.attn_q.weight.lora_b,       torch.float32 --> F16, shape = {16, 1024}
# INFO:hf-to-gguf:blk.12.attn_v.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.12.attn_v.weight.lora_b,       torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.13.ffn_down.weight.lora_a,     torch.float32 --> F16, shape = {2048, 16}
# INFO:hf-to-gguf:blk.13.ffn_down.weight.lora_b,     torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.13.ffn_gate.weight.lora_a,     torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.13.ffn_gate.weight.lora_b,     torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.13.ffn_up.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.13.ffn_up.weight.lora_b,       torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.13.attn_k.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.13.attn_k.weight.lora_b,       torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.13.attn_output.weight.lora_a,  torch.float32 --> F16, shape = {1024, 16}
# INFO:hf-to-gguf:blk.13.attn_output.weight.lora_b,  torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.13.attn_q.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.13.attn_q.weight.lora_b,       torch.float32 --> F16, shape = {16, 1024}
# INFO:hf-to-gguf:blk.13.attn_v.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.13.attn_v.weight.lora_b,       torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.14.ffn_down.weight.lora_a,     torch.float32 --> F16, shape = {2048, 16}
# INFO:hf-to-gguf:blk.14.ffn_down.weight.lora_b,     torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.14.ffn_gate.weight.lora_a,     torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.14.ffn_gate.weight.lora_b,     torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.14.ffn_up.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.14.ffn_up.weight.lora_b,       torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.14.attn_k.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.14.attn_k.weight.lora_b,       torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.14.attn_output.weight.lora_a,  torch.float32 --> F16, shape = {1024, 16}
# INFO:hf-to-gguf:blk.14.attn_output.weight.lora_b,  torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.14.attn_q.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.14.attn_q.weight.lora_b,       torch.float32 --> F16, shape = {16, 1024}
# INFO:hf-to-gguf:blk.14.attn_v.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.14.attn_v.weight.lora_b,       torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.15.ffn_down.weight.lora_a,     torch.float32 --> F16, shape = {2048, 16}
# INFO:hf-to-gguf:blk.15.ffn_down.weight.lora_b,     torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.15.ffn_gate.weight.lora_a,     torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.15.ffn_gate.weight.lora_b,     torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.15.ffn_up.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.15.ffn_up.weight.lora_b,       torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.15.attn_k.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.15.attn_k.weight.lora_b,       torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.15.attn_output.weight.lora_a,  torch.float32 --> F16, shape = {1024, 16}
# INFO:hf-to-gguf:blk.15.attn_output.weight.lora_b,  torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.15.attn_q.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.15.attn_q.weight.lora_b,       torch.float32 --> F16, shape = {16, 1024}
# INFO:hf-to-gguf:blk.15.attn_v.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.15.attn_v.weight.lora_b,       torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.16.ffn_down.weight.lora_a,     torch.float32 --> F16, shape = {2048, 16}
# INFO:hf-to-gguf:blk.16.ffn_down.weight.lora_b,     torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.16.ffn_gate.weight.lora_a,     torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.16.ffn_gate.weight.lora_b,     torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.16.ffn_up.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.16.ffn_up.weight.lora_b,       torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.16.attn_k.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.16.attn_k.weight.lora_b,       torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.16.attn_output.weight.lora_a,  torch.float32 --> F16, shape = {1024, 16}
# INFO:hf-to-gguf:blk.16.attn_output.weight.lora_b,  torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.16.attn_q.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.16.attn_q.weight.lora_b,       torch.float32 --> F16, shape = {16, 1024}
# INFO:hf-to-gguf:blk.16.attn_v.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.16.attn_v.weight.lora_b,       torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.17.ffn_down.weight.lora_a,     torch.float32 --> F16, shape = {2048, 16}
# INFO:hf-to-gguf:blk.17.ffn_down.weight.lora_b,     torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.17.ffn_gate.weight.lora_a,     torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.17.ffn_gate.weight.lora_b,     torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.17.ffn_up.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.17.ffn_up.weight.lora_b,       torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.17.attn_k.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.17.attn_k.weight.lora_b,       torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.17.attn_output.weight.lora_a,  torch.float32 --> F16, shape = {1024, 16}
# INFO:hf-to-gguf:blk.17.attn_output.weight.lora_b,  torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.17.attn_q.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.17.attn_q.weight.lora_b,       torch.float32 --> F16, shape = {16, 1024}
# INFO:hf-to-gguf:blk.17.attn_v.weight.lora_a,       torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.17.attn_v.weight.lora_b,       torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.2.ffn_down.weight.lora_a,      torch.float32 --> F16, shape = {2048, 16}
# INFO:hf-to-gguf:blk.2.ffn_down.weight.lora_b,      torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.2.ffn_gate.weight.lora_a,      torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.2.ffn_gate.weight.lora_b,      torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.2.ffn_up.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.2.ffn_up.weight.lora_b,        torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.2.attn_k.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.2.attn_k.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.2.attn_output.weight.lora_a,   torch.float32 --> F16, shape = {1024, 16}
# INFO:hf-to-gguf:blk.2.attn_output.weight.lora_b,   torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.2.attn_q.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.2.attn_q.weight.lora_b,        torch.float32 --> F16, shape = {16, 1024}
# INFO:hf-to-gguf:blk.2.attn_v.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.2.attn_v.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.3.ffn_down.weight.lora_a,      torch.float32 --> F16, shape = {2048, 16}
# INFO:hf-to-gguf:blk.3.ffn_down.weight.lora_b,      torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.3.ffn_gate.weight.lora_a,      torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.3.ffn_gate.weight.lora_b,      torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.3.ffn_up.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.3.ffn_up.weight.lora_b,        torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.3.attn_k.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.3.attn_k.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.3.attn_output.weight.lora_a,   torch.float32 --> F16, shape = {1024, 16}
# INFO:hf-to-gguf:blk.3.attn_output.weight.lora_b,   torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.3.attn_q.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.3.attn_q.weight.lora_b,        torch.float32 --> F16, shape = {16, 1024}
# INFO:hf-to-gguf:blk.3.attn_v.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.3.attn_v.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.4.ffn_down.weight.lora_a,      torch.float32 --> F16, shape = {2048, 16}
# INFO:hf-to-gguf:blk.4.ffn_down.weight.lora_b,      torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.4.ffn_gate.weight.lora_a,      torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.4.ffn_gate.weight.lora_b,      torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.4.ffn_up.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.4.ffn_up.weight.lora_b,        torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.4.attn_k.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.4.attn_k.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.4.attn_output.weight.lora_a,   torch.float32 --> F16, shape = {1024, 16}
# INFO:hf-to-gguf:blk.4.attn_output.weight.lora_b,   torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.4.attn_q.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.4.attn_q.weight.lora_b,        torch.float32 --> F16, shape = {16, 1024}
# INFO:hf-to-gguf:blk.4.attn_v.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.4.attn_v.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.5.ffn_down.weight.lora_a,      torch.float32 --> F16, shape = {2048, 16}
# INFO:hf-to-gguf:blk.5.ffn_down.weight.lora_b,      torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.5.ffn_gate.weight.lora_a,      torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.5.ffn_gate.weight.lora_b,      torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.5.ffn_up.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.5.ffn_up.weight.lora_b,        torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.5.attn_k.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.5.attn_k.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.5.attn_output.weight.lora_a,   torch.float32 --> F16, shape = {1024, 16}
# INFO:hf-to-gguf:blk.5.attn_output.weight.lora_b,   torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.5.attn_q.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.5.attn_q.weight.lora_b,        torch.float32 --> F16, shape = {16, 1024}
# INFO:hf-to-gguf:blk.5.attn_v.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.5.attn_v.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.6.ffn_down.weight.lora_a,      torch.float32 --> F16, shape = {2048, 16}
# INFO:hf-to-gguf:blk.6.ffn_down.weight.lora_b,      torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.6.ffn_gate.weight.lora_a,      torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.6.ffn_gate.weight.lora_b,      torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.6.ffn_up.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.6.ffn_up.weight.lora_b,        torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.6.attn_k.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.6.attn_k.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.6.attn_output.weight.lora_a,   torch.float32 --> F16, shape = {1024, 16}
# INFO:hf-to-gguf:blk.6.attn_output.weight.lora_b,   torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.6.attn_q.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.6.attn_q.weight.lora_b,        torch.float32 --> F16, shape = {16, 1024}
# INFO:hf-to-gguf:blk.6.attn_v.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.6.attn_v.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.7.ffn_down.weight.lora_a,      torch.float32 --> F16, shape = {2048, 16}
# INFO:hf-to-gguf:blk.7.ffn_down.weight.lora_b,      torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.7.ffn_gate.weight.lora_a,      torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.7.ffn_gate.weight.lora_b,      torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.7.ffn_up.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.7.ffn_up.weight.lora_b,        torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.7.attn_k.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.7.attn_k.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.7.attn_output.weight.lora_a,   torch.float32 --> F16, shape = {1024, 16}
# INFO:hf-to-gguf:blk.7.attn_output.weight.lora_b,   torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.7.attn_q.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.7.attn_q.weight.lora_b,        torch.float32 --> F16, shape = {16, 1024}
# INFO:hf-to-gguf:blk.7.attn_v.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.7.attn_v.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.8.ffn_down.weight.lora_a,      torch.float32 --> F16, shape = {2048, 16}
# INFO:hf-to-gguf:blk.8.ffn_down.weight.lora_b,      torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.8.ffn_gate.weight.lora_a,      torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.8.ffn_gate.weight.lora_b,      torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.8.ffn_up.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.8.ffn_up.weight.lora_b,        torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.8.attn_k.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.8.attn_k.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.8.attn_output.weight.lora_a,   torch.float32 --> F16, shape = {1024, 16}
# INFO:hf-to-gguf:blk.8.attn_output.weight.lora_b,   torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.8.attn_q.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.8.attn_q.weight.lora_b,        torch.float32 --> F16, shape = {16, 1024}
# INFO:hf-to-gguf:blk.8.attn_v.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.8.attn_v.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.9.ffn_down.weight.lora_a,      torch.float32 --> F16, shape = {2048, 16}
# INFO:hf-to-gguf:blk.9.ffn_down.weight.lora_b,      torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.9.ffn_gate.weight.lora_a,      torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.9.ffn_gate.weight.lora_b,      torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.9.ffn_up.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.9.ffn_up.weight.lora_b,        torch.float32 --> F16, shape = {16, 2048}
# INFO:hf-to-gguf:blk.9.attn_k.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.9.attn_k.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:blk.9.attn_output.weight.lora_a,   torch.float32 --> F16, shape = {1024, 16}
# INFO:hf-to-gguf:blk.9.attn_output.weight.lora_b,   torch.float32 --> F16, shape = {16, 640}
# INFO:hf-to-gguf:blk.9.attn_q.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.9.attn_q.weight.lora_b,        torch.float32 --> F16, shape = {16, 1024}
# INFO:hf-to-gguf:blk.9.attn_v.weight.lora_a,        torch.float32 --> F16, shape = {640, 16}
# INFO:hf-to-gguf:blk.9.attn_v.weight.lora_b,        torch.float32 --> F16, shape = {16, 256}
# INFO:hf-to-gguf:Set meta model
# INFO:hf-to-gguf:Set model parameters
# INFO:hf-to-gguf:Set model quantization version
# INFO:hf-to-gguf:Set model tokenizer
# INFO:gguf.gguf_writer:Writing the following files:
# INFO:gguf.gguf_writer:gguf_checkpoints/timer_checkpoint-30f16.gguf: n_tensors = 252, total_size = 7.6M
# Writing: 100%|███████████████████████████| 7.59M/7.59M [00:00<00:00, 248Mbyte/s]
# INFO:lora-to-gguf:Model successfully exported to gguf_checkpoints/timer_checkpoint-30f16.gguf
